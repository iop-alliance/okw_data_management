# %% [markdown]
# <img src="https://pbs.twimg.com/profile_images/1092394418135539713/eplLRcDN_400x400.jpg" width=80px style="text-align:right"><h1>The Internet of Production Alliance </h1>
#
# ## Data collection program for the [OKW, Map of facilities](https://www.internetofproduction.org/open-know-where)

# %% [markdown]
# Author: Antonio de Jesus Anaya Hernandez, DevOps eng. for the IoPA.
#
# Author: The internet of Production Alliance, 2024.
#
# Data was collected by:
#
# 1. "The Fab Foundation, FabLab Network and its partners", URL location: https://api.fablabs.io/0/labs.json
# 2. "Make Works, FabLab Barcelona and its partners", URL location: https://make.works/companies
# 3. "Offene Werkstaetten, and its partners", URL location: https://www.offene-werkstaetten.org/de/werkstatt-suche
# 4. "Field Ready Inc. and its partners", URL location: sftp://acc1079413848@access804698569.webspace-data.io/raw_fieldready_input_2022.csv
# 5. "Makery"
# 6. "MakerTour"
# 7. "Makezine"
# 8. "Bay Area Makerspaces UC Berkeley"
# 9. "Bay Area Makerspaces Upbeatlab"
# 10. "sphere.diybio.org"
# 11. "Hackerspaces.org"
# 12. "Vulca"
# 13. "Data Awards r1"
# 14. "Data Awards r2"
# 15. "IMA"
# 16. "mAkE"
# 17. "FabCity"
# 18. "Univeristy of Michigan 3DLab"
#
# The Open Know Where (OKW) Initiative is part of the Internet of Production Alliance and its members.
#
# License: CC BY SA
#
# ![CC BY SA](https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-sa.svg)
#
# Description: Python code reading the processed IOPA data, determine the country and region by reversed geocoding, and count the total records.
#
# Rev 0, 01/16/2024

# %%
import pandas as pd
import math

# %%
dir_loc = '../data/'

version = 'iopa_'

countries_geo = pd.read_csv(dir_loc + 'countries.csv')
# on later version this line will be replaced by a data validation and normalization data output csv file.

sources = ['iopa_fablabsio_output_2023_11_30_0850.csv', 'iopa_make_works_output_2023_11_30_0625.csv', 'iopa_offene_output_2023_11_30_0306.csv', 'raw_fieldready_input_2022.csv',
          'iopa_makery_output_2024_02_13_0154.csv', 'raw_makertour_input_2024_02_18_0418.csv']

# %%
regions = {}
countries = {}
points = {}
table_regions = {}
table_countries = {}

# %%
for file in sources:
    try:
        points[file] = pd.read_csv(dir_loc + file).dropna(subset = ['latitude', 'longitude', 'country'])
    except KeyError:
        points[file] = pd.read_csv(dir_loc + file).dropna(subset = ['latitude', 'longitude'])
def d(x1, y1, x2, y2):
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# %%
for file in points.values():
    print(file.shape)
    for key, record in file.iterrows():
        dr = float('inf')
        try:
            country_name = record['country']
        except KeyError:
            for ckey, country in countries_geo.iterrows():
                dn = d(record['latitude'], record['longitude'], country['latitude'], country['longitude'])
                if dn < dr:
                    dr = dn
                    region = country['region']
                    country_name = country['name']
                else:
                    dr = dr
                    region = region
                    country_name = country_name
        try:
            countries[country_name] += 1
        except KeyError:
            if not country_name == None:
                countries[country_name] = 1
        # table country create list
        try:
            table_countries[country_name].append(record)
        except KeyError:
            if not country_name == None:
                table_countries[country_name] = [record]
        try:
            regions[region] += 1
        except KeyError:
            if not region == None:
                regions[region] = 1
    print(regions)
    print(sum(regions.values()))
# Out:
# (1879, 15)
# {'Europe': 845, 'Asia': 367, 'Americas': 555, 'Africa': 93, 'Oceania': 19}
# 1879
# (303, 14)
# {'Europe': 1098, 'Asia': 416, 'Americas': 556, 'Africa': 93, 'Oceania': 19}
# 2182
# (480, 11)
# {'Europe': 1098, 'Asia': 896, 'Americas': 556, 'Africa': 93, 'Oceania': 19}
# 2662
# (9498, 65)
# {'Europe': 1098, 'Asia': 10394, 'Americas': 556, 'Africa': 93, 'Oceania': 19}
# 12160
# (528, 13)
# {'Europe': 1527, 'Asia': 10413, 'Americas': 610, 'Africa': 112, 'Oceania': 26}
# 12688
# (151, 8)
# {'Europe': 1678, 'Asia': 10413, 'Americas': 610, 'Africa': 112, 'Oceania': 26}
# 12839

# %%
print(sorted(countries.items(), key=lambda x:x[1], reverse=True))
# Out:
# [('Uganda', 5003), ('Kenya', 3303), ('Bangladesh', 1049), ('Deutschland', 459), ('Belgium', 181), ('France', 154), ('Man (Isle of)', 136), ('United States', 133), ('Iraq', 132), ('United Kingdom', 111), ('Paraguay', 105), ('Andorra', 95), ('Switzerland', 80), ('Bermuda', 79), ('Monaco', 78), ('Jersey', 70), ('Netherlands', 66), ('Mexico', 64), ('United Arab Emirates', 56), ('South Korea', 46), ('Czech Republic', 42), ('Peru', 41), ('Portugal', 41), ('Denmark', 39), ('Germany', 38), ('Spain', 37), ('Liechtenstein', 37), ('Georgia', 37), ('India', 36), ('Luxembourg', 36), ('Vatican City State (Holy See)', 35), ('San Marino', 34), ('Somaliland', 28), ('Sri Lanka', 26), ('Philippines', 26), ('Austria', 26), ('Chile', 26), ('Taiwan', 25), ('Japan', 24), ('Guernsey and Alderney', 24), ('The Bahamas', 23), ('Uruguay', 23), ('Ukraine', 23), ('Brazil', 22), ('Egypt', 18), ('Malta', 18), ('Italy', 17), ('Iceland', 16), ('Slovenia', 16), ('Colombia', 16), ('Bulgaria', 15), ('Singapore', 15), ('Poland', 14), ('Palestinian Territory Occupied', 13), ('Nepal', 13), ('Greece', 13), ('Hong Kong S.A.R.', 12), ('Gibraltar', 12), ('Ireland', 12), ('China', 11), ('Ecuador', 11), ('Estonia', 11), ('Österreich', 11), ('Argentina', 10), ('Pakistan', 9), ('Saint Pierre and Miquelon', 9), ('Israel', 9), ('Saudi Arabia', 9), ('Bahrain', 9), ('Moldova', 8), ('Montenegro', 8), ('Tunisia', 8), ('New Zealand', 8), ('Kazakhstan', 8), ('Cuba', 8), ('Costa Rica', 8), ('Iran', 8), ('Togo', 8), ('French Guiana', 8), ('Australia', 8), ('Hungary', 8), ('Bolivia', 7), ('Faroe Islands', 7), ('Qatar', 7), ('Lithuania', 6), ('Morocco', 6), ('Gambia The', 6), ('Cambodia', 6), ('Laos', 6), ('North Korea', 6), ('Slovakia', 6), ('Suriname', 6), ("Cote D'Ivoire (Ivory Coast)", 6), ('Serbia', 6), ('Schweiz', 6), ('Croatia', 5), ('Belize', 5), ('Reunion', 5), ('Albania', 5), ('Guatemala', 5), ('El Salvador', 5), ('Congo', 5), ('Puerto Rico', 5), ('Aland Islands', 5), ('Norway', 5), ('Finland', 5), ('Russia', 5), ('Cameroon', 4), ('Equatorial Guinea', 4), ('Macau S.A.R.', 4), ('South Africa', 4), ('Christmas Island', 4), ('Canada', 4), ('Kuwait', 4), ('Kyrgyzstan', 4), ('Turkey', 4), ('Bhutan', 4), ('Panama', 4), ('Vietnam', 4), ('Nigeria', 4), ('Aruba', 4), ('Bosnia and Herzegovina', 3), ('Thailand', 3), ('Norfolk Island', 3), ('Swaziland', 3), ('Burkina Faso', 3), ('Lebanon', 3), ('North Macedonia', 3), ('Bonaire, Sint Eustatius and Saba', 3), ('Rwanda', 3), ('New Caledonia', 2), ('Indonesia', 2), ('Ethiopia', 2), ('Armenia', 2), ('Jordan', 2), ('Guinea', 2), ('Tokelau', 2), ('Cyprus', 2), ('Eritrea', 2), ('Griechenland', 2), ('Benin', 1), ('Tanzania', 1), ('Sierra Leone', 1), ('Honduras', 1), ('Madagascar', 1), ('Azerbaijan', 1), ('Jamaica', 1), ('Syria', 1), ('Ghana', 1), ('Lesotho', 1), ('Falkland Islands', 1), ('Djibouti', 1), ('Latvia', 1), ('Oman', 1), ('Mauritania', 1), ('Guadeloupe', 1), ('Chad', 1), ('Western Sahara', 1), ('Trinidad And Tobago', 1), ('Luxemburg', 1), ('Italien', 1), ('Liberia', 1), ('Zambia', 1), ('Kosovo', 1), ('Hong Kong', 1)]

# %%
print(sorted(regions.items(), key=lambda x:x[1], reverse=True))
# Out:
# [('Asia', 10413), ('Europe', 1678), ('Americas', 610), ('Africa', 112), ('Oceania', 26)]

# %%
print(sum(regions.values()))
# Out:
# 12839

# %%
print(int(sum(countries.values())* 8))
# Out:
# 102712

# %%
countries['Uganda']
# Out:
# 5003

# %%
#table_regions

# %%
#table_regions['Europe']

# %%
#table_countries

# %%
len(table_countries)
# Out:
# 165

# %%
table_countries['Mexico']
# Out:
# [Unnamed: 0                                                               164
#  fablabs_id                                                              1415
#  name                                                         Fab Lab Juarez
#  fablabs_kind_name                                                    fab_lab
#  description                Fab Lab Juarez is located in The Borderplex Ar...
#  city                                                           Ciudad Juárez
#  postal_code                                                            32317
#  country_code                                                              MX
#  latitude                                                           31.745403
#  longitude                                                         -106.44863
#  phone                                                         +5216562623132
#  email                                                     info@fablabjrz.org
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/fablabjuarez
#  address                         Avenida López Mateos 924, Alfa., , Chihuahua
#  Name: 141, dtype: object,
#  Unnamed: 0                                                               176
#  fablabs_id                                                               292
#  name                                                          Fab Lab Puebla
#  fablabs_kind_name                                                    fab_lab
#  description                Fab lab Puebla is located within the 91 500+ s...
#  city                                                                  Puebla
#  postal_code                                                            72197
#  country_code                                                              MX
#  latitude                                                           19.031245
#  longitude                                                         -98.242559
#  phone                                          +52 (222) 372 3000 ext. 12910
#  email                                        aristarco.cortes@iberopuebla.mx
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/fablabpuebla
#  address                                Blvd. del Niño Poblano 2901, , Puebla
#  Name: 152, dtype: object,
#  Unnamed: 0                                                               211
#  fablabs_id                                                               713
#  name                                  Marin Country Day School - Makers' Lab
#  fablabs_kind_name                                               mini_fab_lab
#  description                The Makers' Lab started like most things, a si...
#  city                                                            Corte Madera
#  postal_code                                                            94925
#  country_code                                                              US
#  latitude                                                           37.919804
#  longitude                                                        -122.491366
#  phone                                                           415-927-5950
#  email                                                      mpearson@mcds.org
#  fablabs_activity_status                                               active
#  fablabs_url                https://www.fablabs.io/labs/marincountrydaysch...
#  address                                    5221 Paradise Drive, , California
#  Name: 183, dtype: object,
#  Unnamed: 0                                                               325
#  fablabs_id                                                              2205
#  name                                                          Urban Workshop
#  fablabs_kind_name                                                    fab_lab
#  description                Urban Workshop provides the highest caliber of...
#  city                                                              Costa Mesa
#  postal_code                                                            92626
#  country_code                                                              US
#  latitude                                                           33.666494
#  longitude                                                        -117.878669
#  phone                                                             9492962153
#  email                                                 info@urbanworkshop.net
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/urbanworkshop
#  address                              365 Clinton Street, Suite A, California
#  Name: 290, dtype: object,
#  Unnamed: 0                                                               353
#  fablabs_id                                                                85
#  name                                                Stanford Learning FabLab
#  fablabs_kind_name                                                    fab_lab
#  description                                                              NaN
#  city                                                               Palo Alto
#  postal_code                                                            94301
#  country_code                                                              US
#  latitude                                                           37.441883
#  longitude                                                        -122.143019
#  phone                                                                    NaN
#  email                                                                    NaN
#  fablabs_activity_status                                                  NaN
#  fablabs_url                https://www.fablabs.io/labs/stanfordlearningfa...
#  address                                                                  NaN
#  Name: 313, dtype: object,
#  Unnamed: 0                                                               453
#  fablabs_id                                                              1430
#  name                                                             UNAM FABLAB
#  fablabs_kind_name                                                    fab_lab
#  description                UNAM FABLAB has its origins in the Digital Man...
#  city                                                             Mexico City
#  postal_code                                                            04510
#  country_code                                                              MX
#  latitude                                                           19.308846
#  longitude                                                         -99.185684
#  phone                                                      +52 55 5623 7035
#  email                                                 pdi_6@posgrado.unam.mx
#  fablabs_activity_status                                               active
#  fablabs_url                           https://www.fablabs.io/labs/unamfablab
#  address                    Circuito de los Posgrados S/N , Lab. J-006 P.B...
#  Name: 404, dtype: object,
#  Unnamed: 0                                                  504
#  fablabs_id                                                  509
#  name                                            Fab Lab El Paso
#  fablabs_kind_name                                       fab_lab
#  description                                                 NaN
#  city                                                    El Paso
#  postal_code                                               79901
#  country_code                                                 US
#  latitude                                              31.761285
#  longitude                                           -106.490776
#  phone                                              915-209-2656
#  email                                     info@fablabelpaso.org
#  fablabs_activity_status                                  active
#  fablabs_url                https://www.fablabs.io/labs/fablabep
#  address                        601 N Oregon Street, Suite 2, TX
#  Name: 451, dtype: object,
#  Unnamed: 0                                                               679
#  fablabs_id                                                              2473
#  name                                                               FABJARDIN
#  fablabs_kind_name                                                    fab_lab
#  description                Fabjardin is located near of the metropolitan ...
#  city                                                                  Chalco
#  postal_code                                                            56600
#  country_code                                                              MX
#  latitude                                                           19.268588
#  longitude                                                         -98.891126
#  phone                                                             5576571685
#  email                                                     info@fabjardin.com
#  fablabs_activity_status                                               active
#  fablabs_url                            https://www.fablabs.io/labs/fabjardin
#  address                    C. 5 de febrero No. 23 Col. La Bomba, 7495+FG ...
#  Name: 617, dtype: object,
#  Unnamed: 0                                                               724
#  fablabs_id                                                              2183
#  name                                                     Fablab Santa Monica
#  fablabs_kind_name                                                    fab_lab
#  description                The institute Thomas Jefferson campus Santa Mo...
#  city                                                     Tlalnepantla de Baz
#  postal_code                                                            54050
#  country_code                                                              MX
#  latitude                                                           19.525688
#  longitude                                                         -99.231151
#  phone                                                       +52 55 4160 2000
#  email                                                      fablab@itj.edu.mx
#  fablabs_activity_status                                               active
#  fablabs_url                          https://www.fablabs.io/labs/santamonica
#  address                      S. Márquez, Ex-hacienda de Santa Monica, Mexico
#  Name: 659, dtype: object,
#  Unnamed: 0                                                               726
#  fablabs_id                                                              1554
#  name                                                           Fablab Analco
#  fablabs_kind_name                                                    fab_lab
#  description                Fablab Analco is a project conceived by the In...
#  city                                              Heroica Puebla de Zaragoza
#  postal_code                                                              NaN
#  country_code                                                              MX
#  latitude                                                           19.039099
#  longitude                                                         -98.194452
#  phone                                                        +52 222 6051926
#  email                                       cooperativafabanalco@hotmail.com
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/fablabanalco
#  address                        7 Oriente #805, Planta alta, Analco, , Puebla
#  Name: 661, dtype: object,
#  Unnamed: 0                                                               811
#  fablabs_id                                                              1188
#  name                                                        FabLab Querétaro
#  fablabs_kind_name                                                    fab_lab
#  description                Fablab dedicated to taking innovation to every...
#  city                                                              El Marqués
#  postal_code                                                            76246
#  country_code                                                              MX
#  latitude                                                           20.589354
#  longitude                                                        -100.390756
#  phone                                                         +524422456742
#  email                                                   fablabqro@anahuac.mx
#  fablabs_activity_status                                               active
#  fablabs_url                            https://www.fablabs.io/labs/fablabqro
#  address                    Universidad Anáhuac Querétaro, Calle Universid...
#  Name: 740, dtype: object,
#  Unnamed: 0                                                               813
#  fablabs_id                                                              2044
#  name                                                       FabLab La Campana
#  fablabs_kind_name                                               mini_fab_lab
#  description                Lugar diseñado para fomentar la participacion ...
#  city                                                               Monterrey
#  postal_code                                                            64765
#  country_code                                                              MX
#  latitude                                                           25.638579
#  longitude                                                        -100.304949
#  phone                                                                    NaN
#  email                                              pascual.milan89@gmail.com
#  fablabs_activity_status                                               active
#  fablabs_url                            https://www.fablabs.io/labs/lacampana
#  address                    Laderas del Mirador, Laderas del Mirador, Nuev...
#  Name: 741, dtype: object,
#  Unnamed: 0                                                               882
#  fablabs_id                                                              2347
#  name                                                               FAB LABNL
#  fablabs_kind_name                                                    fab_lab
#  description                LABNL, Lab Cultural Ciudadano, es un espacio p...
#  city                                                               Monterrey
#  postal_code                                                            64600
#  country_code                                                              MX
#  latitude                                                           25.686614
#  longitude                                                        -100.316113
#  phone                                                               81403000
#  email                                           proyectolabnl@conarte.org.mx
#  fablabs_activity_status                                               active
#  fablabs_url                                https://www.fablabs.io/labs/labnl
#  address                                                  Washignton  648, ,
#  Name: 802, dtype: object,
#  Unnamed: 0                                                               889
#  fablabs_id                                                               706
#  name                                                            Fab Lab UANL
#  fablabs_kind_name                                                    fab_lab
#  description                El Fab Lab UANL, tiene como misión impulsar la...
#  city                                                San Nicolás de los Garza
#  postal_code                                                            66400
#  country_code                                                              MX
#  latitude                                                           25.725818
#  longitude                                                        -100.311132
#  phone                                                     83294160 ext. 6755
#  email                                               evert.sanchezg@gmail.com
#  fablabs_activity_status                                                  NaN
#  fablabs_url                           https://www.fablabs.io/labs/fablabuanl
#  address                               San Nicolás de los Garza, , Nuevo Leon
#  Name: 809, dtype: object,
#  Unnamed: 0                                                               901
#  fablabs_id                                                               540
#  name                       Castlemont High School, Sustainable Urban Desi...
#  fablabs_kind_name                                                    fab_lab
#  description                The Sustainable Urban Design Academy (SUDA) at...
#  city                                                                 Oakland
#  postal_code                                                            94605
#  country_code                                                              US
#  latitude                                                           37.759174
#  longitude                                                        -122.163726
#  phone                                                                    NaN
#  email                                             castlemontfablab@gmail.com
#  fablabs_activity_status                                                  NaN
#  fablabs_url                 https://www.fablabs.io/labs/sudacastlemontfablab
#  address                                              8601 MacArthur Blvd, ,
#  Name: 820, dtype: object,
#  Unnamed: 0                                                       1086
#  fablabs_id                                                         86
#  name                                                Fab Lab San Diego
#  fablabs_kind_name                                             fab_lab
#  description                                                       NaN
#  city                                                        San Diego
#  postal_code                                                     92111
#  country_code                                                       US
#  latitude                                                    32.715329
#  longitude                                                 -117.157255
#  phone                                                      6192003256
#  email                                              katie@fablabsd.org
#  fablabs_activity_status                                           NaN
#  fablabs_url                https://www.fablabs.io/labs/fablabsandiego
#  address                              4685 Convoy St, #200, California
#  Name: 979, dtype: object,
#  Unnamed: 0                                                              1091
#  fablabs_id                                                              1354
#  name                             California State University Dominguez Hills
#  fablabs_kind_name                                                    fab_lab
#  description                The CSUDH Mobile Fab Lab project is at the for...
#  city                                                                  Carson
#  postal_code                                                            90747
#  country_code                                                              US
#  latitude                                                           33.866278
#  longitude                                                        -118.254558
#  phone                                                           310-243-3232
#  email                                                  fablabscsudh@csi3.org
#  fablabs_activity_status                                                  NaN
#  fablabs_url                https://www.fablabs.io/labs/californiastateuni...
#  address                                     1000 E Victoria St, , California
#  Name: 984, dtype: object,
#  Unnamed: 0                                                              1102
#  fablabs_id                                                              1744
#  name                                       Port Product Lab / Elevator Works
#  fablabs_kind_name                                                    fab_lab
#  description                We are partnered with the largest independent ...
#  city                                                                 Oakland
#  postal_code                                                            94612
#  country_code                                                              US
#  latitude                                                           37.814249
#  longitude                                                        -122.289313
#  phone                                                           510.900.9719
#  email                                                    info@elevator.works
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/elevatorworks
#  address                                                    344 20th st, , CA
#  Name: 992, dtype: object,
#  Unnamed: 0                                                              1117
#  fablabs_id                                                              1394
#  name                                                    Laney College FabLab
#  fablabs_kind_name                                                    fab_lab
#  description                Laney College FabLab, founded in the year 2015...
#  city                                                                 Oakland
#  postal_code                                                            94607
#  country_code                                                              US
#  latitude                                                           37.796866
#  longitude                                                        -122.263148
#  phone                                                             4153091170
#  email                                                  laneyfablab@gmail.com
#  fablabs_activity_status                                               active
#  fablabs_url                   https://www.fablabs.io/labs/laneycollegefablab
#  address                                                  900 Fallon St, , ca
#  Name: 1005, dtype: object,
#  Unnamed: 0                                                              1187
#  fablabs_id                                                              1785
#  name                                                          Circuit Launch
#  fablabs_kind_name                                                    fab_lab
#  description                Circuit Launch is a coworking, colocating spac...
#  city                                                                 Oakland
#  postal_code                                                            94621
#  country_code                                                              US
#  latitude                                                           37.740358
#  longitude                                                        -122.201632
#  phone                                                         (510) 306-1217
#  email                                                   hi@circuitlaunch.com
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/circuitlaunch
#  address                                                8000 Edgewater Dr, ,
#  Name: 1071, dtype: object,
#  Unnamed: 0                                                              1236
#  fablabs_id                                                              1931
#  name                                                            Proyectil Mx
#  fablabs_kind_name                                                    fab_lab
#  description                ProyectilMx is an open space where entrepreneu...
#  city                                                Delegación Benito Juarez
#  postal_code                                                            03100
#  country_code                                                              MX
#  latitude                                                           19.392936
#  longitude                                                          -99.16586
#  phone                                                             5567232258
#  email                                                      info@proyectil.mx
#  fablabs_activity_status                                               active
#  fablabs_url                          https://www.fablabs.io/labs/proyectilmx
#  address                    Mier y Pesado 349 - 2, Colonia del Valle, Ciud...
#  Name: 1110, dtype: object,
#  Unnamed: 0                                                              1241
#  fablabs_id                                                               546
#  name                                            Fab Lab Richmond, California
#  fablabs_kind_name                                                    fab_lab
#  description                Fab Lab Richmond is part of the West Contra Co...
#  city                                                                Richmond
#  postal_code                                                            94804
#  country_code                                                              US
#  latitude                                                           37.925435
#  longitude                                                            -122.33
#  phone                                                           510-307-4567
#  email                                                  pgonsalves@wccusd.net
#  fablabs_activity_status                                                  NaN
#  fablabs_url                https://www.fablabs.io/labs/fablabrichmondcali...
#  address                                      4300 Cutting Blvd, , California
#  Name: 1115, dtype: object,
#  Unnamed: 0                                                              1260
#  fablabs_id                                                               800
#  name                                                          FAB LAB IMPACT
#  fablabs_kind_name                                                    fab_lab
#  description                Fablab Impact is an open innovation center loc...
#  city                                                        Ciudad de México
#  postal_code                                                            06000
#  country_code                                                              MX
#  latitude                                                           19.439655
#  longitude                                                         -99.134222
#  phone                                                                    NaN
#  email                                                          fab@impact.mx
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/fablabimpact
#  address                                         República de Perú 88, , CDMX
#  Name: 1131, dtype: object,
#  Unnamed: 0                                                              1337
#  fablabs_id                                                              1450
#  name                                                            UTRGV FABLAB
#  fablabs_kind_name                                                    fab_lab
#  description                Housed primarily in the jewelry studio within ...
#  city                                                                Edinburg
#  postal_code                                                            78539
#  country_code                                                              US
#  latitude                                                           26.278818
#  longitude                                                         -98.167579
#  phone                                                           956-665-3480
#  email                                                       fablab@utrgv.edu
#  fablabs_activity_status                                               active
#  fablabs_url                          https://www.fablabs.io/labs/utrgvfablab
#  address                                         2412 S Closner Blvd, , Texas
#  Name: 1192, dtype: object,
#  Unnamed: 0                                                              1365
#  fablabs_id                                                              1532
#  name                                                       Hexlab Makerspace
#  fablabs_kind_name                                                    fab_lab
#  description                HexLab Makerspace is a community workshop givi...
#  city                                                              Chatsworth
#  postal_code                                                            91311
#  country_code                                                              US
#  latitude                                                           34.241379
#  longitude                                                        -118.601456
#  phone                                                           818-530-7900
#  email                                           contact@hexlabmakerspace.com
#  fablabs_activity_status                                                  NaN
#  fablabs_url                     https://www.fablabs.io/labs/hexlabmakerspace
#  address                                            9410 Owensmouth Ave, , CA
#  Name: 1216, dtype: object,
#  Unnamed: 0                                                              1377
#  fablabs_id                                                               709
#  name                                                            HackerGarage
#  fablabs_kind_name                                               mini_fab_lab
#  description                HackerGarage is built by designers, developers...
#  city                                                             Guadalajara
#  postal_code                                                            44150
#  country_code                                                              MX
#  latitude                                                           20.671575
#  longitude                                                        -103.372141
#  phone                                                     +52 1 331 064 9996
#  email                                                   info@hackergarage.mx
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/hackergarage
#  address                    Miguel Lerdo de Tejada 2186, Col. Lafayette, J...
#  Name: 1225, dtype: object,
#  Unnamed: 0                                                              1421
#  fablabs_id                                                               126
#  name                                                Fab Lab Ciudad de México
#  fablabs_kind_name                                                    fab_lab
#  description                The Fab Lab Mexico City has become one of the ...
#  city                                                             Mexico City
#  postal_code                                                            52786
#  country_code                                                              MX
#  latitude                                                           19.402062
#  longitude                                                         -99.263932
#  phone                                          : +52 (55) 5627 0210 ext 8326
#  email                                    mexicofablab@universidad.anahuac.mx
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/fablabmexico
#  address                    Universidad Anáhuac México Norte, Av. Universi...
#  Name: 1261, dtype: object,
#  Unnamed: 0                                                              1432
#  fablabs_id                                                              1690
#  name                                                        Cruces Creatives
#  fablabs_kind_name                                                    fab_lab
#  description                Cruces Creatives is a volunteer-led 501(c)(3) ...
#  city                                                              Las Cruces
#  postal_code                                                            88001
#  country_code                                                              US
#  latitude                                                           32.306864
#  longitude                                                        -106.776463
#  phone                                                           575-448-1072
#  email                                               info@crucescreatives.org
#  fablabs_activity_status                                               active
#  fablabs_url                      https://www.fablabs.io/labs/crucescreatives
#  address                                       205 E Lohman Ave, , New Mexico
#  Name: 1269, dtype: object,
#  Unnamed: 0                                                              1478
#  fablabs_id                                                              2246
#  name                                                         FAB LAB NOVAERA
#  fablabs_kind_name                                                    fab_lab
#  description                El objetivo principal del Fab Lab Novaera es f...
#  city                                                                    León
#  postal_code                                                            37320
#  country_code                                                              MX
#  latitude                                                           21.129995
#  longitude                                                        -101.685796
#  phone                                                       +521477 688 6748
#  email                                                     agomez@novaera.com
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/fablabnovaera
#  address                    Julián de Obregón #245, Col. Obregón., , Guana...
#  Name: 1304, dtype: object,
#  Unnamed: 0                                                              1488
#  fablabs_id                                                               372
#  name                                                        FABLAB Chihuahua
#  fablabs_kind_name                                                    fab_lab
#  description                FABLAB Chihuahua has a flexible manufacturing ...
#  city                                                               Chihuahua
#  postal_code                                                            31300
#  country_code                                                              MX
#  latitude                                                           28.673977
#  longitude                                                        -106.079358
#  phone                                                     +52(614) 424 01 66
#  email                                           contacto@fablabchihuahua.com
#  fablabs_activity_status                                                  NaN
#  fablabs_url                      https://www.fablabs.io/labs/fablabchihuahua
#  address                    Av. Heroico colegio militar #4709 Colonia Nomb...
#  Name: 1314, dtype: object,
#  Unnamed: 0                                                     1584
#  fablabs_id                                                      612
#  name                       California State University, Bakersfield
#  fablabs_kind_name                                           fab_lab
#  description                                                     NaN
#  city                                                    Bakersfield
#  postal_code                                                   93311
#  country_code                                                     US
#  latitude                                                  35.373278
#  longitude                                               -119.017628
#  phone                                                           NaN
#  email                                                           NaN
#  fablabs_activity_status                                         NaN
#  fablabs_url                        https://www.fablabs.io/labs/CSUB
#  address                        9001 Stockdale Highway, , California
#  Name: 1393, dtype: object,
#  Unnamed: 0                                                              1637
#  fablabs_id                                                              1852
#  name                                                         Fab Lab Tijuana
#  fablabs_kind_name                                                    fab_lab
#  description                Fab Lab Tijuana started as an iniciative from ...
#  city                                                                 Tijuana
#  postal_code                                                            22253
#  country_code                                                              MX
#  latitude                                                           32.518254
#  longitude                                                         -117.03974
#  phone                                                        01 664 199 4476
#  email                                       saul.salas@tijuanainnovadora.com
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/fablabtijuana
#  address                    Consorcio Tecnologico S/N , , Baja California,...
#  Name: 1435, dtype: object,
#  Unnamed: 0                                                              1731
#  fablabs_id                                                              1078
#  name                                                            CREATE+BUILD
#  fablabs_kind_name                                                    fab_lab
#  description                \r\nOur acronymic names, CREATE (Creativity, R...
#  city                                                           San Francisco
#  postal_code                                                            94132
#  country_code                                                              US
#  latitude                                                           37.713285
#  longitude                                                        -122.475599
#  phone                                                             4154061035
#  email                                                     c_b@sfbrandeis.org
#  fablabs_activity_status                                                  NaN
#  fablabs_url                          https://www.fablabs.io/labs/createbuild
#  address                    The Brandeis School of San Francisco, 655 Brot...
#  Name: 1514, dtype: object,
#  Unnamed: 0                                                              1733
#  fablabs_id                                                              1081
#  name                                              Bay Area Discovery Museum
#  fablabs_kind_name                                                    fab_lab
#  description                The Early Childhood Fab Lab at the Bay Area Di...
#  city                                                               Sausalito
#  postal_code                                                            94965
#  country_code                                                              US
#  latitude                                                           37.835591
#  longitude                                                        -122.476401
#  phone                                                           415-339-3900
#  email                                                       contact@badm.org
#  fablabs_activity_status                                                  NaN
#  fablabs_url                https://www.fablabs.io/labs/bayareadiscoverymu...
#  address                                              557 McReynolds Rd, , CA
#  Name: 1516, dtype: object,
#  Unnamed: 0                                                              1737
#  fablabs_id                                                              1100
#  name                                                                FABWorks
#  fablabs_kind_name                                                    fab_lab
#  description                In an effort to expand experiential learning o...
#  city                                                                  Irvine
#  postal_code                                                            92697
#  country_code                                                              US
#  latitude                                                            33.64286
#  longitude                                                        -117.841205
#  phone                                                           949-824-5667
#  email                                                       shovsep1@uci.edu
#  fablabs_activity_status                                                  NaN
#  fablabs_url                             https://www.fablabs.io/labs/fabworks
#  address                                    Calit2, UCI Campus, Rm 2302, , CA
#  Name: 1520, dtype: object,
#  Unnamed: 0                                                              1765
#  fablabs_id                                                              1163
#  name                                    Parque de Innovación Tecnológica UAS
#  fablabs_kind_name                                                    fab_lab
#  description                A través de los esfuerzos institucionales el D...
#  city                                                        Culiacán Rosales
#  postal_code                                                              NaN
#  country_code                                                              MX
#  latitude                                                           24.823186
#  longitude                                                        -107.379728
#  phone                                                    (+52) 667-758-14-24
#  email                                                         pit@uas.edu.mx
#  fablabs_activity_status                                                  NaN
#  fablabs_url                https://www.fablabs.io/labs/parquedeinnovacint...
#  address                                 Josefa Ortiz de Domínguez, , Sinaloa
#  Name: 1543, dtype: object,
#  Unnamed: 0                                                              1900
#  fablabs_id                                                              1658
#  name                                                           Ciudad Retoño
#  fablabs_kind_name                                                    fab_lab
#  description                Ciudad Retoño is located in the municipality L...
#  city                                                                     NaN
#  postal_code                                                           56420
#  country_code                                                              MX
#  latitude                                                           19.359972
#  longitude                                                         -98.984649
#  phone                                                             +523723000
#  email                                         alberto.camacho@iberopuebla.mx
#  fablabs_activity_status                                               active
#  fablabs_url                         https://www.fablabs.io/labs/ciudadretono
#  address                                                 , , Estado de México
#  Name: 1660, dtype: object,
#  Unnamed: 0                                                              1946
#  fablabs_id                                                              2327
#  name                                                              Hub Center
#  fablabs_kind_name                                               mini_fab_lab
#  description                We started as an interdisciplinary co-creation...
#  city                                                                Ensenada
#  postal_code                                                            22830
#  country_code                                                              MX
#  latitude                                                           31.859455
#  longitude                                                        -116.610906
#  phone                                                          +526462061221
#  email                                                    fablab@hubcenter.mx
#  fablabs_activity_status                                               active
#  fablabs_url                            https://www.fablabs.io/labs/hubcenter
#  address                                      Av Rayon 294, , Baja California
#  Name: 1702, dtype: object,
#  Unnamed: 0                                                              1977
#  fablabs_id                                                              1449
#  name                                                                 SAL-LAB
#  fablabs_kind_name                                                    fab_lab
#  description                The Autonomous Systems Laboratory "Raúl Rojas ...
#  city                                                   Santiago de Querétaro
#  postal_code                                                            76090
#  country_code                                                              MX
#  latitude                                                           20.574018
#  longitude                                                        -100.369688
#  phone                                                       +52-442-1223-829
#  email                                                         salas@ieee.org
#  fablabs_activity_status                                               active
#  fablabs_url                               https://www.fablabs.io/labs/SALLAB
#  address                                        Cerro Blanco 141, , Querétaro
#  Name: 1727, dtype: object,
#  Unnamed: 0                                                              1980
#  fablabs_id                                                              1865
#  name                       FabLab Centro de Desarrollo Tecnológico Zinaca...
#  fablabs_kind_name                                               mini_fab_lab
#  description                Our university wants to be part of this Projec...
#  city                                                            Zinacantepec
#  postal_code                                                            51355
#  country_code                                                              MX
#  latitude                                                           19.306171
#  longitude                                                         -99.715746
#  phone                                                          +527221542791
#  email                                                     jlebario@gmail.com
#  fablabs_activity_status                                               active
#  fablabs_url                https://www.fablabs.io/labs/fablabCEDETECzinac...
#  address                    Antonio Pliego Villalba #120, Casa 52, Privada...
#  Name: 1730, dtype: object,
#  Unnamed: 0                                                              1983
#  fablabs_id                                                              1891
#  name                                                             CoA Fab Lab
#  fablabs_kind_name                                                    fab_lab
#  description                At the College of Alameda (CoA) Fab Lab, we em...
#  city                                                                 Alameda
# ...
#  fablabs_kind_name                                                    fab_lab
#  description                Somos parte de la Escuela de Arquitectura y Di...
#  city                                                          Tlaxcalancingo
#  postal_code                                                            72810
#  country_code                                                              MX
#  latitude                                                           19.021206
#  longitude                                                         -98.262985
#  phone                                                    2221691069 Ext. 302
#  email                                                 jose.diazbe@anahuac.mx
#  fablabs_activity_status                                               active
#  fablabs_url                        https://www.fablabs.io/labs/fablabanahuac
#  address                    Av Orion Nte S/N, Magisterio 2000 I, 72810 Tla...
#  Name: 1901, dtype: object,
#  Unnamed: 0                                                              2193
#  fablabs_id                                                              2209
#  name                                               FabLab La Salle Chihuahua
#  fablabs_kind_name                                                    fab_lab
#  description                This project, Fab Lab La Salle Chihuahua, repr...
#  city                                                               Chihuahua
#  postal_code                                                            31625
#  country_code                                                              MX
#  latitude                                                           28.609655
#  longitude                                                        -106.129413
#  phone                                                          +556144321474
#  email                                            clopez@ulsachihuahua.edu.mx
#  fablabs_activity_status                                               active
#  fablabs_url                     https://www.fablabs.io/labs/LaSalleChihauhua
#  address                    Prolongación Lómas de Majalca No. 11201 Coloni...
#  Name: 1919, dtype: object,
#  Unnamed: 0                                                              2209
#  fablabs_id                                                              2176
#  name                                                 Fab Lab Paso del Norte
#  fablabs_kind_name                                                    fab_lab
#  description                El Fablab debe servir como apoyo a emprendimie...
#  city                                                                  Juarez
#  postal_code                                                            32575
#  country_code                                                              MX
#  latitude                                                           31.598314
#  longitude                                                        -106.362437
#  phone                                                       +52 656 262 3132
#  email                                                   samuel@fablabjrz.org
#  fablabs_activity_status                                               active
#  fablabs_url                   https://www.fablabs.io/labs/fablabpasodelnorte
#  address                    Río del Norte 906, Manuel J. Clouthier, 32575 ...
#  Name: 1933, dtype: object,
#  Unnamed: 0                                                         22
#  makery_id                                                          hF
#  name                                                     Double Union
#  createdAt                                   2023-10-19T20:51:34+02:00
#  updatedAt                                   2023-12-18T10:28:52+01:00
#  makery_status                                                       1
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                       http://www.doubleunion.org/
#  email                                                         private
#  latitude                                                    37.760851
#  longitude                                                 -122.411333
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Double-...
#  address_composed       650H, Florida Street, San Francisco, 94110, us
#  Name: 22, dtype: object,
#  Unnamed: 0                                                        104
#  makery_id                                                          rh
#  name                                                  BioPunk Society
#  createdAt                                   2023-12-06T04:10:35+01:00
#  updatedAt                                   2023-12-06T09:26:47+01:00
#  makery_status                                                       1
#  categories          ['Biolab', 'Biohacking', 'Courses', 'Foodlab',...
#  url                                        https://biopunksociety.com
#  email                                                         private
#  latitude                                                    37.770855
#  longitude                                                 -122.413571
#  makery_url          https://makery.gogocarto.fr/map#/fiche/BioPunk...
#  address_composed         43, Norfolk Street, San Francisco, 94103, us
#  Name: 104, dtype: object,
#  Unnamed: 0                                                        241
#  makery_id                                                          dj
#  name                                                       Biocurious
#  createdAt                                   2023-10-19T20:51:33+02:00
#  updatedAt                                   2023-10-19T20:51:33+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                            http://biocurious.org/
#  email                                                             NaN
#  latitude                                                      37.3771
#  longitude                                                    -121.973
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Biocuri...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 241, dtype: object,
#  Unnamed: 0                                                        242
#  makery_id                                                          dl
#  name                                                   Biotech&Beyond
#  createdAt                                   2023-10-19T20:51:33+02:00
#  updatedAt                                   2023-10-19T20:51:33+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                        http://biotechnbeyond.com/
#  email                                                             NaN
#  latitude                                                    33.135599
#  longitude                                                    -117.275
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Biotech...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 242, dtype: object,
#  Unnamed: 0                                                        244
#  makery_id                                                          dr
#  name                                             Counter Culture Labs
#  createdAt                                   2023-10-19T20:51:33+02:00
#  updatedAt                                   2023-10-19T20:51:33+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                    https://counterculturelabs.org
#  email                                                             NaN
#  latitude                                                       37.835
#  longitude                                                    -122.264
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Counter...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 244, dtype: object,
#  Unnamed: 0                                                        257
#  makery_id                                                          es
#  name                                                   Fablab El Paso
#  createdAt                                   2023-10-19T20:51:33+02:00
#  updatedAt                                   2023-10-19T20:51:33+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                           http://fablabelpaso.org
#  email                                                             NaN
#  latitude                                                      31.7673
#  longitude                                                    -106.486
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Fablab-...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 257, dtype: object,
#  Unnamed: 0                                                        265
#  makery_id                                                          fB
#  name                                                    HeatSync Labs
#  createdAt                                   2023-10-19T20:51:33+02:00
#  updatedAt                                   2023-10-19T20:51:33+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                      http://www.heatsynclabs.org/
#  email                                                             NaN
#  latitude                                                      33.4153
#  longitude                                                    -111.836
#  makery_url          https://makery.gogocarto.fr/map#/fiche/HeatSyn...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 265, dtype: object,
#  Unnamed: 0                                                        361
#  makery_id                                                          jQ
#  name                                             Hacedores Makerspace
#  createdAt                                   2023-10-19T20:51:34+02:00
#  updatedAt                                   2023-10-19T20:51:34+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                  http://makerspace.hacedores.com/
#  email                                                         private
#  latitude                                                      19.4351
#  longitude                                                    -99.1333
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Hacedor...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 361, dtype: object,
#  Unnamed: 0                                                        362
#  makery_id                                                          jT
#  name                                            El Rancho Electronico
#  createdAt                                   2023-10-19T20:51:34+02:00
#  updatedAt                                   2023-10-19T20:51:34+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                     http://ranchoelectronico.org/
#  email                                                             NaN
#  latitude                                                      19.4234
#  longitude                                                    -99.1446
#  makery_url          https://makery.gogocarto.fr/map#/fiche/El-Ranc...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 362, dtype: object,
#  Unnamed: 0                                                        363
#  makery_id                                                          jU
#  name                                                        Media Lab
#  createdAt                                   2023-10-19T20:51:34+02:00
#  updatedAt                                   2023-10-19T20:51:34+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                            http://medialabmx.org/
#  email                                                             NaN
#  latitude                                                      19.4523
#  longitude                                                    -99.1565
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Media-L...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 363, dtype: object,
#  Unnamed: 0                                                        405
#  makery_id                                                          l5
#  name                                                          Umakers
#  createdAt                                   2023-10-19T20:51:34+02:00
#  updatedAt                                   2023-10-19T20:51:34+02:00
#  makery_status                                                       3
#  categories          ['Fablab', 'Digital fabrication', 'Assistance,...
#  url                                           http://www.umakers.org/
#  email                                                         private
#  latitude                                                      34.1072
#  longitude                                                    -117.698
#  makery_url          https://makery.gogocarto.fr/map#/fiche/Umakers...
#  address_composed                              nan, nan, nan, nan, nan
#  Name: 405, dtype: object,
#  Unnamed: 0                                                   76
#  name                                         La Nave Makerspace
#  city                                           Ciudad de México
#  country                                                  Mexico
#  tags                                             ['Makerspace']
#  url           https://www.makertour.fr/workshops/la-nave-mak...
#  latitude                                              19.414275
#  longitude                                            -99.131666
#  Name: 76, dtype: object,
#  Unnamed: 0                                                  77
#  name                                             Fablab Analco
#  city                                Heroica Puebla de Zaragoza
#  country                                                 Mexico
#  tags                       ['Craftmen cooperative', 'Fab Lab']
#  url           https://www.makertour.fr/workshops/fablab-analco
#  latitude                                             19.039078
#  longitude                                           -98.194142
#  Name: 77, dtype: object,
#  Unnamed: 0                                                   78
#  name                                              Fablab Puebla
#  city                                 Heroica Puebla de Zaragoza
#  country                                                  Mexico
#  tags          ['Fab Lab', 'School workshop', 'Coworking space']
#  url            https://www.makertour.fr/workshops/fablab-puebla
#  latitude                                              19.028386
#  longitude                                            -98.227908
#  Name: 78, dtype: object,
#  Unnamed: 0                                                   79
#  name                                       Hacedores Makerspace
#  city                                           Ciudad de México
#  country                                                  Mexico
#  tags                                             ['Makerspace']
#  url           https://www.makertour.fr/workshops/hacedores-m...
#  latitude                                              19.435176
#  longitude                                            -99.133403
#  Name: 79, dtype: object]
