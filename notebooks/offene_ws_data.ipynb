# %% [markdown]
# <img src="https://pbs.twimg.com/profile_images/1092394418135539713/eplLRcDN_400x400.jpg" width=80px style="text-align:right"><h1>The Internet of Production Alliance </h1>
#
# ## Data collection program for the [OKW, Map of facilities](https://www.internetofproduction.org/open-know-where)

# %% [markdown]
# Author: Antonio de Jesus Anaya Hernandez, DevOps eng. for the IoPA.
#
# Author: The internet of Production Alliance, 2023.
#
# Data was collected by "Offene Werkstaetten, and its partners", URL location: https://www.offene-werkstaetten.org/de/werkstatt-suche
#
# The Open Know Where (OKW) Initiative is part of the Internet of Production Alliance and its members.
#
# License: CC BY SA
#
# ![CC BY SA](https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-sa.svg)
#
# Description: Python code for downloading, parsing, filtering, sorting data, exporting the RAW FabLabs, and the processed IOPA data as CSV.

# %%
# This line installs the required libraries for running the script, uncomment the line:
# !pip install -r requirements.txt

# %%
import requests, json, re, time
import pandas as pd

# %%
from datetime import datetime
now = datetime.now()

# %%
from bs4 import BeautifulSoup as soup

# %%
def req_data(url):
    
    response = requests.get(url)
    

    print(response.status_code)
    
    if response.status_code == 200:
        time.sleep(2)
        print(url)
        return response
    else:
        print("Error response: Check URL or internet avalability, and Try again.")
        print(url)
        return req_data(url)

# %%
url = "https://www.offene-werkstaetten.org/widgets/search?colorA=74ac61&colorB=0489B1&customMarkerSrc=https://cdn0.iconfinder.com/data/icons/map-location-solid-style/91/Map_-_Location_Solid_Style_06-48.png&customClusterSrc=https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-circle-filled-48.png"
data = [x.text for x in soup(req_data(url).text, 'html.parser').find_all('script') if 'vow.Map' in x.text][-1]
# Out:
# 200
# https://www.offene-werkstaetten.org/widgets/search?colorA=74ac61&colorB=0489B1&customMarkerSrc=https://cdn0.iconfinder.com/data/icons/map-location-solid-style/91/Map_-_Location_Solid_Style_06-48.png&customClusterSrc=https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-circle-filled-48.png

# %%
data_f = '[{"' + re.findall(r'\[{"(.*?)"\}\]\,', data)[0] + '"}]'
data_json = json.loads(data_f)

# %%
input_ = pd.DataFrame(data_json)

# %%
input_.reset_index(drop=True, inplace=True)

# %%
input_.to_csv('raw_offene_input_' + now.strftime("%Y_%m_%d_%H%M") + '.csv')

# %%
input_.columns.tolist()
# Out:
# ['name',
#  'img',
#  'uid',
#  'url',
#  'lat',
#  'lng',
#  'street',
#  'zip',
#  'city',
#  'web',
#  'country',
#  'cats',
#  'aai',
#  'icm',
#  'street_nr']

# %%
transform = input_.rename(columns={'uid': 'offene_id', 'lat': 'latitude', 'lng': 'longitude', 'zip':'postal_code'})

# %%
transform['offene_url'] = 'https://www.offene-werkstaetten.org/werkstatt/' + transform.url

# %%
transform['address'] = transform.street.astype(str) + ', ' + transform.street_nr + ', ' + transform.aai

# %%
def decrypt(js):
    if js != None:
        # print(js)
        a_cut = js[17:104].replace('\\', '')
        c_cut = js[123:181].replace('\\', '')
                                    
        #print(a_cut)
        #print(c_cut)
        try: 
            a = re.search(re.compile(r'var a="(.*?)";'), a_cut).group(1)
            c = re.search(re.compile(r'var c="(.*?)";'), c_cut).group(1)
        except AttributeError:
            return None
        #print(a)
        #print(c)
        b = ''.join(sorted(a))
        d = ''

        for e in c:
            d += b[a.index(e)]
        #print(d)
        return d
    else:
        print("offline?")
        return None

# %%
transform['contact_email']  = transform.offene_url.apply(lambda x: decrypt(soup(req_data(x).content, 'html.parser').find('span', text=re.compile(r'javascript protected email address')).find_next_sibling('script').text))
# Out:
# 200
# https://www.offene-werkstaetten.org/werkstatt/rosenwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/35-services-e-v-offene-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/360-raum-fuer-kreativitaet
# 200
# https://www.offene-werkstaetten.org/werkstatt/3d-druckzentrum-ruhr
# 200
# https://www.offene-werkstaetten.org/werkstatt/3d-repaircafe-de
# 200
# https://www.offene-werkstaetten.org/werkstatt/4830
# 200
# https://www.offene-werkstaetten.org/werkstatt/abantu-kulturlabor
# 200
# https://www.offene-werkstaetten.org/werkstatt/akademie-fuer-suffizienz
# 200
# https://www.offene-werkstaetten.org/werkstatt/aktivitetshuset
# 200
# https://www.offene-werkstaetten.org/werkstatt/allweshape
# 200
# https://www.offene-werkstaetten.org/werkstatt/alte-giesserei-berlin-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/asta-fahrradwerkstatt-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-fuer-keramik
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-im-sandkasten
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-micaela-de
# 200
# https://www.offene-werkstaetten.org/werkstatt/machwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/atilier
# 200
# https://www.offene-werkstaetten.org/werkstatt/attraktor
# 200
# https://www.offene-werkstaetten.org/werkstatt/augustusburg-aufweiterflur-im-lehngericht
# 200
# https://www.offene-werkstaetten.org/werkstatt/ausbesserungswert
# 200
# https://www.offene-werkstaetten.org/werkstatt/awiro-rostock
# 200
# https://www.offene-werkstaetten.org/werkstatt/awo-offene-werkstatt-rudolstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/backspace-hackerspace-bamberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/bastelbude-grade-de
# 200
# https://www.offene-werkstaetten.org/werkstatt/bauer-planer
# 200
# https://www.offene-werkstaetten.org/werkstatt/bicycle-liberation-front-bamberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/bike-kitchen-nuernberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikebox
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-augsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-muenchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-rosenheim
# 200
# https://www.offene-werkstaetten.org/werkstatt/binary-kitchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/biopunk-kitchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/bonn-im-wandel
# 200
# https://www.offene-werkstaetten.org/werkstatt/brigkmakerspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/brinke-26-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/build-share-repair
# 200
# https://www.offene-werkstaetten.org/werkstatt/bukiprojekt-buchkinder-potsdam
# 200
# https://www.offene-werkstaetten.org/werkstatt/namespace
# 200
# https://www.offene-werkstaetten.org/werkstatt/cafekaputt
# 200
# https://www.offene-werkstaetten.org/werkstatt/ccc-ffm
# 200
# https://www.offene-werkstaetten.org/werkstatt/ccc-hh
# 200
# https://www.offene-werkstaetten.org/werkstatt/chance-action-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaoschemnitz
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaosstuff
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaostreff-dortmund
# 200
# https://www.offene-werkstaetten.org/werkstatt/citylab-berlin
# 200
# https://www.offene-werkstaetten.org/werkstatt/cocolab
# 200
# https://www.offene-werkstaetten.org/werkstatt/code-for-heilbronn
# 200
# https://www.offene-werkstaetten.org/werkstatt/colorlabor
# 200
# https://www.offene-werkstaetten.org/werkstatt/comakingspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/coyote
# 200
# https://www.offene-werkstaetten.org/werkstatt/craftschoepferey
# 200
# https://www.offene-werkstaetten.org/werkstatt/creapolis-makerspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/creativhalle-neuss
# 200
# https://www.offene-werkstaetten.org/werkstatt/cucula
# 200
# https://www.offene-werkstaetten.org/werkstatt/curious-community-labs
# 200
# https://www.offene-werkstaetten.org/werkstatt/habitat-augsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/dasdigidings
# 200
# https://www.offene-werkstaetten.org/werkstatt/devlab-tsa-e-v-hackerspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/dezentrale-dortmund
# 200
# https://www.offene-werkstaetten.org/werkstatt/dezentrale-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-blaue-blume
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-ganzmacher-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-machbar
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-motte
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-radgeber
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-werke-bonn-fahrrad-selbsthilfe-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/digitales-aachen-e-v-digitac
# 200
# https://www.offene-werkstaetten.org/werkstatt/dingfabrik
# 200
# https://www.offene-werkstaetten.org/werkstatt/diy-werkstatt-karlsruhe
# 200
# https://www.offene-werkstaetten.org/werkstatt/diy-holzwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/do-it-yourself-werkstatt-wilhelmshaven
# 200
# https://www.offene-werkstaetten.org/werkstatt/dolab
# 200
# https://www.offene-werkstaetten.org/werkstatt/dorfscheune-praedikow
# 200
# https://www.offene-werkstaetten.org/werkstatt/druckbar
# 200
# https://www.offene-werkstaetten.org/werkstatt/druckgrafisches-atelier
# 200
# https://www.offene-werkstaetten.org/werkstatt/e-werk-oschatz
# 200
# https://www.offene-werkstaetten.org/werkstatt/ecocurious
# 200
# https://www.offene-werkstaetten.org/werkstatt/Ehrenwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/eigenbaukombinat-halle-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/enzwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/erfindergarden
# 200
# https://www.offene-werkstaetten.org/werkstatt/freie-maker
# 200
# https://www.offene-werkstaetten.org/werkstatt/fabulous-st-pauli
# 200
# https://www.offene-werkstaetten.org/werkstatt/fab66
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-aachen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-altmuehlfranken
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ansbach
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-bruchsal
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablabc
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-cottbus
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-frechen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-freising
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-hamm
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ideenreich
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ingolstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-karlsruhe-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-kiel
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-landkreis-fuerth-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-leipzig
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-lengerich
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-luebeck
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-lueneburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-luenen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-muenchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-muenster
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-neckar-alb-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-neuenstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-neustadt-a-d-aisch
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-nuernberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-rothenburg-o-d-t-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-wuerzburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/ifllab
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-bremen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-paderborn-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-siegen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-thueringen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fabmobil
# 200
# https://www.offene-werkstaetten.org/werkstatt/gaengeviertel
# 200
# https://www.offene-werkstaetten.org/werkstatt/fahrrad-und-verkehrs-ag-des-asta-der-tu-braunschweig
# 200
# https://www.offene-werkstaetten.org/werkstatt/fahrrad3000
# 200
# https://www.offene-werkstaetten.org/werkstatt/fahrradwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/faradgang-koeln
# 200
# https://www.offene-werkstaetten.org/werkstatt/farbraum-muenchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/fau-fablab
# 200
# https://www.offene-werkstaetten.org/werkstatt/fazze
# 200
# https://www.offene-werkstaetten.org/werkstatt/filmhaus-koeln
# 200
# https://www.offene-werkstaetten.org/werkstatt/flicken-berlin
# 200
# https://www.offene-werkstaetten.org/werkstatt/flipdot-hackerspace-kassel
# 200
# https://www.offene-werkstaetten.org/werkstatt/flow-lernort-welt
# 200
# https://www.offene-werkstaetten.org/werkstatt/fluktus-werkstaetten
# 200
# https://www.offene-werkstaetten.org/werkstatt/forscherbox
# 200
# https://www.offene-werkstaetten.org/werkstatt/frauenhandwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/freie-stiftung
# 200
# https://www.offene-werkstaetten.org/werkstatt/freie-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/freies-labor-hildesheim
# 200
# https://www.offene-werkstaetten.org/werkstatt/freilab
# 200
# https://www.offene-werkstaetten.org/werkstatt/freiraum-hackerspace-ulm
# 200
# https://www.offene-werkstaetten.org/werkstatt/freiRAUM-Angermuende
# 200
# https://www.offene-werkstaetten.org/werkstatt/freiRAUM-Prenzlau
# 200
# https://www.offene-werkstaetten.org/werkstatt/freiRAUM-Templin
# 200
# https://www.offene-werkstaetten.org/werkstatt/freischrauber
# 200
# https://www.offene-werkstaetten.org/werkstatt/freiwerk-paderborn
# 200
# https://www.offene-werkstaetten.org/werkstatt/fzwd
# 200
# https://www.offene-werkstaetten.org/werkstatt/garagelab-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/gemeinschaftswerkstatt-spreisselwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/gesta-aschaffenburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/glasbox-bht
# 200
# https://www.offene-werkstaetten.org/werkstatt/goodlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/gutalaune
# 200
# https://www.offene-werkstaetten.org/werkstatt/habibi-works
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackerspace-bielefeld-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackerspace-bremen-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackerspace-ffm
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackerspace-saarbruecken
# 200
# https://www.offene-werkstaetten.org/werkstatt/hacklabor
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackspace-jena
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackspace-marburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/hackspace-siegen
# 200
# https://www.offene-werkstaetten.org/werkstatt/hafven
# 200
# https://www.offene-werkstaetten.org/werkstatt/halle-1
# 200
# https://www.offene-werkstaetten.org/werkstatt/halle36
# 200
# https://www.offene-werkstaetten.org/werkstatt/halle-temp
# 200
# https://www.offene-werkstaetten.org/werkstatt/hammertime
# 200
# https://www.offene-werkstaetten.org/werkstatt/hwg-freiburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/hansawerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/happylab-berlin
# 200
# https://www.offene-werkstaetten.org/werkstatt/haus-der-eigenarbeit
# 200
# https://www.offene-werkstaetten.org/werkstatt/haxko
# 200
# https://www.offene-werkstaetten.org/werkstatt/heart-of-code
# 200
# https://www.offene-werkstaetten.org/werkstatt/hebewerk-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/himmelsgruen-malatelier
# 200
# https://www.offene-werkstaetten.org/werkstatt/hinsche
# 200
# https://www.offene-werkstaetten.org/werkstatt/hobbyhimmel
# 200
# https://www.offene-werkstaetten.org/werkstatt/hofalab
# 200
# https://www.offene-werkstaetten.org/werkstatt/holz-werk-stadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzhilfe
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzhof-nischwitz
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzkombinat
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzkraftwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzwerkstatt-gostenhof
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzwerkstatt-hausdrei
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzwerkstatt-im-treffpunkt-freizeit
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzwerkstatt-regenbogenfabrik
# 200
# https://www.offene-werkstaetten.org/werkstatt/holzwerkstaettin-kubiz-wallenberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/honigfabrik
# 200
# https://www.offene-werkstaetten.org/werkstatt/hrw-fablab
# 200
# https://www.offene-werkstaetten.org/werkstatt/hub-spoke
# 200
# https://www.offene-werkstaetten.org/werkstatt/hubschrauber
# 200
# https://www.offene-werkstaetten.org/werkstatt/ideenwerkstadt-stuttgart
# 200
# https://www.offene-werkstaetten.org/werkstatt/ikuwo
# 200
# https://www.offene-werkstaetten.org/werkstatt/illenau-werkstaetten
# 200
# https://www.offene-werkstaetten.org/werkstatt/innovationswerkstatt-konstanz
# 200
# https://www.offene-werkstaetten.org/werkstatt/innwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/jugendkulturhaus-dynamo
# 200
# https://www.offene-werkstaetten.org/werkstatt/kabutze
# 200
# https://www.offene-werkstaetten.org/werkstatt/kanal
# 200
# https://www.offene-werkstaetten.org/werkstatt/kanthaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/kaos
# 200
# https://www.offene-werkstaetten.org/werkstatt/keller-5-die-offene-fahrradwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/kempodium
# 200
# https://www.offene-werkstaetten.org/werkstatt/klax-kreativwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/klecksx
# 200
# https://www.offene-werkstaetten.org/werkstatt/klimaquartier-ellener-hof
# 200
# https://www.offene-werkstaetten.org/werkstatt/klimaquartier-ellener-hof-naehwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/KlimaWerkStadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/kofferwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/KoLab
# 200
# https://www.offene-werkstaetten.org/werkstatt/konrad
# 200
# https://www.offene-werkstaetten.org/werkstatt/kreativgarage-im-ackermannbogen
# 200
# https://www.offene-werkstaetten.org/werkstatt/kreativkellerei
# 200
# https://www.offene-werkstaetten.org/werkstatt/kreativwerkstatt-ffm
# 200
# https://www.offene-werkstaetten.org/werkstatt/krimZkrams
# 200
# https://www.offene-werkstaetten.org/werkstatt/kuehlhaus-goerlitz
# 200
# https://www.offene-werkstaetten.org/werkstatt/kultur-botschaft-berlin-lichtenberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/kulturlabortrial-error
# 200
# https://www.offene-werkstaetten.org/werkstatt/kulturmarkthalle
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunst-ort-lehnin
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunst-und-kultur-bastei-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunst-werk-stadt-berlin-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunst-stoffe
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunstkollektiv-jaffe
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunstwerk-jena
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunstwerkstatt-mohrvilla
# 200
# https://www.offene-werkstaetten.org/werkstatt/kunstwerkstatt-samariterstrasse
# 200
# https://www.offene-werkstaetten.org/werkstatt/lab
# 200
# https://www.offene-werkstaetten.org/werkstatt/lama-fahrradselbsthilfewerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/land-leben-kunst-werk
# 200
# https://www.offene-werkstaetten.org/werkstatt/landkombinat-gatschow
# 200
# https://www.offene-werkstaetten.org/werkstatt/lastenvelo-freiburg-selbsthilfewerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/lccfablab
# 200
# https://www.offene-werkstaetten.org/werkstatt/leinelab
# 200
# https://www.offene-werkstaetten.org/werkstatt/les-bricoleurs
# 200
# https://www.offene-werkstaetten.org/werkstatt/linienhof-offene-metallwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/louloute
# 200
# https://www.offene-werkstaetten.org/werkstatt/lutherlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/machbar-im-wuermtal
# 200
# https://www.offene-werkstaetten.org/werkstatt/machbar-potsdam
# 200
# https://www.offene-werkstaetten.org/werkstatt/macherburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/machwerk-hennef
# 200
# https://www.offene-werkstaetten.org/werkstatt/mainframe
# 200
# https://www.offene-werkstaetten.org/werkstatt/maked-digital-lb
# 200
# https://www.offene-werkstaetten.org/werkstatt/maked-digital-us
# 200
# https://www.offene-werkstaetten.org/werkstatt/makeraustria
# 200
# https://www.offene-werkstaetten.org/werkstatt/maker-lab-murnau
# 200
# https://www.offene-werkstaetten.org/werkstatt/MakerPop
# 200
# https://www.offene-werkstaetten.org/werkstatt/maker-werkstadt-frankfurt
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerhafen
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerkutsche
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-amsham
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-baiersdorf
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-bocholt
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-bonn
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-darmstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-der-stadtbibliothek-bielefeld
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-esslingen
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-experimenta
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-geistesblitz
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-giessen
# 200
# https://www.offene-werkstaetten.org/werkstatt/rabryka
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-gotha
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-greifswald
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-guetersloh
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-kassel
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-minden
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-niesky
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-rhein-neckar
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-viernheim
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-wiesbaden
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-wittlich
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-aurich
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-erfurt
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-hochschule-niederrhein
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-kaarst
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-leipzig
# 200
# https://www.offene-werkstaetten.org/werkstatt/makertreff-reutlingen
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-ebe
# 200
# https://www.offene-werkstaetten.org/werkstatt/manu-die-offene-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/maschinendeck
# 200
# https://www.offene-werkstaetten.org/werkstatt/materialbuffet
# 200
# https://www.offene-werkstaetten.org/werkstatt/meffis
# 200
# https://www.offene-werkstaetten.org/werkstatt/meta-lab-rhein-ruhr
# 200
# https://www.offene-werkstaetten.org/werkstatt/metallwerkstatt-ajz-bielefeld
# 200
# https://www.offene-werkstaetten.org/werkstatt/metrolab-berlin
# 200
# https://www.offene-werkstaetten.org/werkstatt/minitopia-alternation-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/mode-kollektiv-mengenich
# 200
# https://www.offene-werkstaetten.org/werkstatt/mode-kollektiv
# 200
# https://www.offene-werkstaetten.org/werkstatt/motion-lab
# 200
# https://www.offene-werkstaetten.org/werkstatt/muenchner-werkzeugbibliothek
# 200
# https://www.offene-werkstaetten.org/werkstatt/munichmakerlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/nachbarschafft-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/nachbarschaftsgaerten
# 200
# https://www.offene-werkstaetten.org/werkstatt/wunschnachbarn
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehpoint
# 200
# https://www.offene-werkstaetten.org/werkstatt/nagel-und-faden-geretsried
# 200
# https://www.offene-werkstaetten.org/werkstatt/naeh-werk
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehbar-im-kuba
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehcaf-kiel
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehcafe-zeitlos
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehsalon
# 200
# https://www.offene-werkstaetten.org/werkstatt/naehzimmer-offene-schneiderei-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/nerdberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/netz39
# 200
# https://www.offene-werkstaetten.org/werkstatt/c3d2
# 200
# https://www.offene-werkstaetten.org/werkstatt/netzwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/niemandsland
# 200
# https://www.offene-werkstaetten.org/werkstatt/nobreakspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/ob-ej-kt-die-werkstatt-fuer-jedermann
# 200
# https://www.offene-werkstaetten.org/werkstatt/oberlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-holzwerkstatt-borsdorf
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-jugendwerkstatt-karlsruhe
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-jugendwerkstatt-st-ingbert
# 200
# https://www.offene-werkstaetten.org/werkstatt/wrg
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-am-stadtwald
# 200
# https://www.offene-werkstaetten.org/werkstatt/owba
# 200
# https://www.offene-werkstaetten.org/werkstatt/mia-maedchen-in-aktion
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-gilching
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-gudwork
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-k20
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-lutherplatz
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-mainz
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-metall
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-norderstedt
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-spremberg
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstaette-weiz-thannhausen
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-freising
# 200
# https://www.offene-werkstaetten.org/werkstatt/offener-werkstatt-treff-und-inklusives-fablab
# 200
# https://www.offene-werkstaetten.org/werkstatt/ok-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/open-source-ecology-germany-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/open-lab-hamburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/openguitar
# 200
# https://www.offene-werkstaetten.org/werkstatt/openlab-augsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/openmycolab
# 200
# https://www.offene-werkstaetten.org/werkstatt/osw-leipzig
# 200
# https://www.offene-werkstaetten.org/werkstatt/papierwerk-glockenbach
# 200
# https://www.offene-werkstaetten.org/werkstatt/paul-dohrmann-schule
# 200
# https://www.offene-werkstaetten.org/werkstatt/planraum
# 200
# https://www.offene-werkstaetten.org/werkstatt/plattenladen-kollektiv
# 200
# https://www.offene-werkstaetten.org/werkstatt/platzprojekt
# 200
# https://www.offene-werkstaetten.org/werkstatt/polytechnischer-werkraum-zittau
# 200
# https://www.offene-werkstaetten.org/werkstatt/precious-plastic-altona
# 200
# https://www.offene-werkstaetten.org/werkstatt/precious-plastic-muenchen
# 200
# https://www.offene-werkstaetten.org/werkstatt/protohaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/quellkollektiv
# 200
# https://www.offene-werkstaetten.org/werkstatt/rad-i-o
# 200
# https://www.offene-werkstaetten.org/werkstatt/rad-team-leibnitz-gymnasium-essen
# 200
# https://www.offene-werkstaetten.org/werkstatt/radikate
# 200
# https://www.offene-werkstaetten.org/werkstatt/radkueche-muenze
# 200
# https://www.offene-werkstaetten.org/werkstatt/radsfatz
# 200
# https://www.offene-werkstaetten.org/werkstatt/raum-wagen
# 200
# https://www.offene-werkstaetten.org/werkstatt/raumfahrtagentur
# 200
# https://www.offene-werkstaetten.org/werkstatt/raumzeitlabor
# 200
# https://www.offene-werkstaetten.org/werkstatt/rebycle
# 200
# https://www.offene-werkstaetten.org/werkstatt/ressourcenzentrum
# 200
# https://www.offene-werkstaetten.org/werkstatt/rio-raum
# 200
# https://www.offene-werkstaetten.org/werkstatt/rollwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/rueckenwind-selbsthilfewerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/st-darmstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/schaffbar-bb
# 200
# https://www.offene-werkstaetten.org/werkstatt/schaffenburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/schafferei
# 200
# https://www.offene-werkstaetten.org/werkstatt/schmackomat
# 200
# https://www.offene-werkstaetten.org/werkstatt/schmiede-im-hof-berlin
# 200
# https://www.offene-werkstaetten.org/werkstatt/schmiedfeuer-werkstatt-und-beratung
# 200
# https://www.offene-werkstaetten.org/werkstatt/schnittstelle
# 200
# https://www.offene-werkstaetten.org/werkstatt/schokowerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/schoepfwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/sdw-neukoelln
# 200
# https://www.offene-werkstaetten.org/werkstatt/sekundaer-schick
# 200
# https://www.offene-werkstaetten.org/werkstatt/selbsthilfefahrradwerkstatt-fh-erfurt
# 200
# https://www.offene-werkstaetten.org/werkstatt/selbstwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/selfmade
# 200
# https://www.offene-werkstaetten.org/werkstatt/shackspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/siebdruck-atelier-posa
# 200
# https://www.offene-werkstaetten.org/werkstatt/siebdruckwerkstatt-k4
# 200
# https://www.offene-werkstaetten.org/werkstatt/silberfabrik
# 200
# https://www.offene-werkstaetten.org/werkstatt/skills-factory
# 200
# https://www.offene-werkstaetten.org/werkstatt/slub-makerspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/sonnenlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/passage13
# 200
# https://www.offene-werkstaetten.org/werkstatt/stadt-teil-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/stadtteilraum
# 200
# https://www.offene-werkstaetten.org/werkstatt/station-wsw
# 200
# https://www.offene-werkstaetten.org/werkstatt/sternenlabor
# 200
# https://www.offene-werkstaetten.org/werkstatt/stoffdeck-co-working-wilhelmsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/stratum0
# 200
# https://www.offene-werkstaetten.org/werkstatt/straze
# 200
# https://www.offene-werkstaetten.org/werkstatt/streifenholz
# 200
# https://www.offene-werkstaetten.org/werkstatt/studentenwerkstatt-aachen-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/swablab
# 200
# https://www.offene-werkstaetten.org/werkstatt/tagwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/teamwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/technikfreunde
# 200
# https://www.offene-werkstaetten.org/werkstatt/TechBil
# 200
# https://www.offene-werkstaetten.org/werkstatt/temporaerhaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/testwerkstatt-mario-2
# 200
# https://www.offene-werkstaetten.org/werkstatt/th-brandenburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/the-brake
# 200
# https://www.offene-werkstaetten.org/werkstatt/thfwelcomefahrradprojekt
# 200
# https://www.offene-werkstaetten.org/werkstatt/tinkertank
# 200
# https://www.offene-werkstaetten.org/werkstatt/toolbox-bodensee-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/tooltime
# 200
# https://www.offene-werkstaetten.org/werkstatt/toppoint-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/transition-town-augsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/transition-town-witzenhausen-projekthaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/transitionhaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/treffen-und-machen
# 200
# https://www.offene-werkstaetten.org/werkstatt/treibgut
# 200
# https://www.offene-werkstaetten.org/werkstatt/tuedeleck
# 200
# https://www.offene-werkstaetten.org/werkstatt/tueftelwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/turbine
# 200
# https://www.offene-werkstaetten.org/werkstatt/unhb
# 200
# https://www.offene-werkstaetten.org/werkstatt/unikat
# 200
# https://www.offene-werkstaetten.org/werkstatt/unternehmen-chance
# 200
# https://www.offene-werkstaetten.org/werkstatt/unternehmertum-makerspace-gmbh
# 200
# https://www.offene-werkstaetten.org/werkstatt/upcyclingwerkstatt-hannover
# 200
# https://www.offene-werkstaetten.org/werkstatt/urban-lab
# 200
# https://www.offene-werkstaetten.org/werkstatt/urbanisten-manufaktur
# 200
# https://www.offene-werkstaetten.org/werkstatt/ursprung-frankfurt
# 200
# https://www.offene-werkstaetten.org/werkstatt/utopiawerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/velo-caf
# 200
# https://www.offene-werkstaetten.org/werkstatt/verstehbahnhof
# 200
# https://www.offene-werkstaetten.org/werkstatt/vetomat
# 200
# https://www.offene-werkstaetten.org/werkstatt/erlebniswerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/vinnlab
# 200
# https://www.offene-werkstaetten.org/werkstatt/volldabei-fahrrad-club
# 200
# https://www.offene-werkstaetten.org/werkstatt/von-herz
# 200
# https://www.offene-werkstaetten.org/werkstatt/vspace-one
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt-petersburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/wagnis-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/wak-lab
# 200
# https://www.offene-werkstaetten.org/werkstatt/wandelwerk
# 200
# https://www.offene-werkstaetten.org/werkstatt/wehrke-westen
# 200
# https://www.offene-werkstaetten.org/werkstatt/welcome-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/weneedhomesffm
# 200
# https://www.offene-werkstaetten.org/werkstatt/werk-2
# 200
# https://www.offene-werkstaetten.org/werkstatt/werk-und-raum
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkundkultur
# 200
# https://www.offene-werkstaetten.org/werkstatt/werk-stadtpiraten
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadtladen-loebtau
# 200
# https://www.offene-werkstaetten.org/werkstatt/werk
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkbox-vs
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkbox3
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkhaus-potsdam
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkimpuls
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkraum-augsburg
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkraum47
# 200
# https://www.offene-werkstaetten.org/werkstatt/werksalon-co-making-space
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkschule-lambach
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadt
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadthall
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadthaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-hoeflich
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-im-jukuz
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-karli17
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-lindenau
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattcouch
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstaetten-im-horte-soziales-zentrum
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstaetten-im-museum-altranft
# 200
# https://www.offene-werkstaetten.org/werkstatt/traumschule-riebau
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatthaus
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatthaus-allerhand-e-v
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattkollektiv-plan-b
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattkonsum
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattraum
# 200
# https://www.offene-werkstaetten.org/werkstatt/wir-werkstudio-im-richardkiez
# 200
# https://www.offene-werkstaetten.org/werkstatt/wir-bauen-zukunft
# 200
# https://www.offene-werkstaetten.org/werkstatt/wirfoerdern-e-v-offene-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/wolkenschachlenk-werkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/wucholtzky
# 200
# https://www.offene-werkstaetten.org/werkstatt/wurmloch
# 200
# https://www.offene-werkstaetten.org/werkstatt/xhain-hack-makerspace
# 200
# https://www.offene-werkstaetten.org/werkstatt/xyz-cargo-n55-till-wolfer
# 200
# https://www.offene-werkstaetten.org/werkstatt/z-bau-nordgarten
# 200
# https://www.offene-werkstaetten.org/werkstatt/zam
# 200
# https://www.offene-werkstaetten.org/werkstatt/zircula-lab
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-suedpfalz
# 200
# https://www.offene-werkstaetten.org/werkstatt/zum-rostigen-ross
# 200
# https://www.offene-werkstaetten.org/werkstatt/zwanzig-selbsthilfe-fahrradwerkstatt
# 200
# https://www.offene-werkstaetten.org/werkstatt/zweiradcaf

# %%
output = transform.drop(columns=['img', 'street', 'street_nr', 'aai', 'cats', 'url', 'icm', 'web'])

# %%
output.to_csv('iopa_offene_output_' + now.strftime("%Y_%m_%d_%H%M") + '.csv')

# %%
print("OKW entries: {r[0]}, columns = {r[1]}".format(r=output.shape))
# Out:
# OKW entries: 482, columns = 10
