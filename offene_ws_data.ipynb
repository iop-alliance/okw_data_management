# %% [markdown]
# <img src="https://pbs.twimg.com/profile_images/1092394418135539713/eplLRcDN_400x400.jpg" width=80px style="text-align:right"><h1>The Internet of Production Alliance </h1>
#
# ## Data collection program for the [OKW, Map of facilities](https://www.internetofproduction.org/open-know-where)

# %% [markdown]
# Author: Antonio de Jesus Anaya Hernandez, DevOps eng. for the IoPA.
#
# Author: The internet of Production Alliance, 2023.
#
# Data was collected by "The Fab Foundation, FabLab Network and its partners", URL location: https://api.fablabs.io/0/labs.json
#
# The Open Know Where (OKW) Initiative is part of the Internet of Production Alliance and its members.
#
# License: CC BY SA
#
# ![CC BY SA](https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-sa.svg)
#
# Description: Python code for downloading, parsing, filtering, sorting data, exporting the RAW FabLabs, and the processed IOPA data as CSV.

# %%
# This line installs the required libraries for running the script, uncomment the line:
# !pip install -r requirements.txt

# %%
import requests, json, re, time
import pandas as pd

# %%
from datetime import datetime
now = datetime.now()

# %%
from bs4 import BeautifulSoup as soup

# %%
def req_data(url):
    
    response = requests.get(url)
    

    print(response.status_code)
    
    if response.status_code == 200:
        time.sleep(2)
        print(url)
        return response
    else:
        print("Error response: Check URL or internet avalability, and Try again.")
        print(url)

# %%
url = "https://www.offene-werkstaetten.org/widgets/search?colorA=74ac61&colorB=0489B1&customMarkerSrc=https://cdn0.iconfinder.com/data/icons/map-location-solid-style/91/Map_-_Location_Solid_Style_06-48.png&customClusterSrc=https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-circle-filled-48.png"
data = [x.text for x in soup(req_data(url).text, 'html.parser').find_all('script') if 'vow.Map' in x.text][-1]
# Out:
# 200
# https://www.offene-werkstaetten.org/widgets/search?colorA=74ac61&colorB=0489B1&customMarkerSrc=https://cdn0.iconfinder.com/data/icons/map-location-solid-style/91/Map_-_Location_Solid_Style_06-48.png&customClusterSrc=https://cdn4.iconfinder.com/data/icons/ionicons/512/icon-ios7-circle-filled-48.png

# %%
data_f = '[{"' + re.findall(r'\[{"(.*?)"\}\]\,', data)[0] + '"}]'
data_json = json.loads(data_f)

# %%
input_ = pd.DataFrame(data_json)

# %%
input_.reset_index(drop=True, inplace=True)

# %%
input_.to_csv('raw_offene_input_' + now.strftime("%Y_%m_%d_%H%M") + '.csv')

# %%
input_.columns.tolist()
# Out:
# ['name',
#  'img',
#  'uid',
#  'url',
#  'lat',
#  'lng',
#  'street',
#  'zip',
#  'city',
#  'web',
#  'country',
#  'cats',
#  'aai',
#  'icm',
#  'street_nr']

# %%
transform = input_.rename(columns={'uid': 'offene_id', 'lat': 'latitude', 'lng': 'longitude', 'zip':'postal_code'})

# %%
transform['offene_url'] = 'https://www.offene-werkstaetten.org/werkstatt/' + transform.url

# %%
transform['address'] = transform.street.astype(str) + ', ' + transform.street_nr + ', ' + transform.aai

# %%
transform['span_email_encrypted'] = transform.offene_url.apply(lambda x: print(soup(req_data(x).content, 'html.parser').find('span', text=re.compile(r'javascript protected email address')).find_next_sibling('script')))
# Out:
# 200
# https://www.offene-werkstaetten.org/werkstatt/rosenwerk
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"B5d+TwvfqK.XjHrJc4PWgVtpMAsyn9I@hZEkFNSL0u_-GiR6bazx1Y3mo7eU2lOCD8Q\";var b=a.split(\"\").sort().join(\"\");var c=\"OmeU2u3GHxm361mYieu2dme6\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e621999299\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/35-services-e-v-offene-werkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vVrE2uiqgSwGHdJeTZFt+A_4X.5-shUPoYW8j7xDQKfO13cB0LylbNzmnR6pCMa@I9k\";var b=a.split(\"\").sort().join(\"\");var c=\"Lzcmdigp36aLO3pr13\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e207390426\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/360-raum-fuer-kreativitaet
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"r@ON+H7Iy1mBG8iQFqM_AJuKp5VtZaoxER0es-L9vzlg4dW6.nYXPSCDUbhj2kcwTf3\";var b=a.split(\"\").sort().join(\"\");var c=\"nCWD871N6hz4@Png.2dCldh6O4d\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e344101251\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/3d-druckzentrum-ruhr
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"EVujwNknY9m23vC._Lhp1SUF0O6lbtc7sRdeqf5agPTI+xDBH@Kyo8WirG-ZAJzMX4Q\";var b=a.split(\"\").sort().join(\"\");var c=\"yiWAPyAvk+V+-JIyQxWA-J8V-JH-u+x\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e177731958\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/3d-repaircafe-de
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"HrRObfT+Zes8_GFJq.dLzDgtX0MUlmo1naQcpjx@hYAyiBw49N2K3-IP57vukEVSWC6\";var b=a.split(\"\").sort().join(\"\");var c=\"-YKBrNkGTirvB5YNvqYwBRiB\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e376501548\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/4830
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"n4fu_5-3iO9lwDJ+GRhF1c0PQHM.NU@EsBTjWVxaCKZ8bpdk6mSXog2qvrzAyt7YLIe\";var b=a.split(\"\").sort().join(\"\");var c=\"m2dqD3l-ufqzk\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e998969569\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/abantu-kulturlabor
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"VvNAZMqlk7@E.hcILDK_sxTdwa4jrX5nRJ2ib90W3GPO-p1BmH8yUCtzYQeoguSfF6+\";var b=a.split(\"\").sort().join(\"\");var c=\"UpetfpUgpthBCFN-p\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e959378392\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/akademie-fuer-suffizienz
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"@ENvFL56_3DYwIV0lyPMeqxng7h9CUsTGtrHuABRp1Si.zX4-ZOjJo+2fQk8mcbKadW\";var b=a.split(\"\").sort().join(\"\");var c=\"i2kZ++1Nb288zIf28mz2N.z\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e208141227\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/aktivitetshuset
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"94LAr-RMiHyX8@dp2VgK1.jOFNIJU_b+63xfwBYhGPDamuQtsEScq0v7TolZznkWCe5\";var b=a.split(\"\").sort().join(\"\");var c=\"PczE@ZmnLmu\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e491478898\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/allweshape
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"5A_UVSt3bDmHre.q2CWIMPZhcuJLlwKikznv+Rg96EaG@14T7FyjfsoB08-pONXdYxQ\";var b=a.split(\"\").sort().join(\"\");var c=\"sBFoeEffd1p7E01_B-T\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e367061464\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/alte-giesserei-berlin-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"SOhK7jl@dU2BEq4g5JX.Gyma8TV30_uYLktIPZWcRwbnNHzsAv-DpCQe+6F9of1rMix\";var b=a.split(\"\").sort().join(\"\");var c=\"wpoHhsvH99HFHvhbHFpvQqseespHCwvphneC\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e822577388\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/offene-werkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"I9iCLmesqMU53vAQDjY4cBz6XVlgaTPJo02E7wpFkZ8tSfhHndNbrGR1.x-K@Wu+Oy_\";var b=a.split(\"\").sort().join(\"\");var c=\"NW+fv@uhbiSf\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e117583689\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/asta-fahrradwerkstatt-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"0P-emqgwsGEopbWR@XkICLZ2aY6D9VAtFiy+.vhfnQ75c8j34xNJld_uMSUBT1rzOHK\";var b=a.split(\"\").sort().join(\"\");var c=\"Ju_TQJTbWFTWPIQ4UUQcz8UJBTQTT-c8\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e567363256\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-fuer-keramik
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Okzca7S-BY9ms.Ky2wXuMTF5rU60AqvgW1RfINEet8GD_obZi3QnJjxpH+L@dVhlCP4\";var b=a.split(\"\").sort().join(\"\");var c=\"3xbp.n3x_oLnoL8j3nz_o\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e685937431\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-im-sandkasten
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"dxgOCKIJAtEpH6T1fjGraUqZi.8@2_swQ-RzcuFXVb5DhW+mlk03B9Ln7ey4SvPMoNY\";var b=a.split(\"\").sort().join(\"\");var c=\"kL+n6k9x4bLh3b4SWLgDl\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e49679945\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/atelier-micaela-de
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"GHCwFErQnvxh5u2Tl+IPMB8XKOLN_RsgdZ0kWbq7fDjpi@J6Vca1-.Uz4meo3S9YytA\";var b=a.split(\"\").sort().join(\"\");var c=\"D3@-c@eH.cpD@-Du6.yCi@\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e584880926\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/machwerk
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"_XwD3ZlbTrs4q.dk6vVta+n@oNeYh2OG1mA9Jx7Ipy0PL5WMgiEFfRUcQK-u8CjHSBz\";var b=a.split(\"\").sort().join(\"\");var c=\"Ryif.RyPgH5-FXRC5UPg5UwL5\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e502238088\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/atilier
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"SxuCIHZkR-Vq8DYiKMcoXe+f9s3l7_.hOQBGA@4NpWTgJvLzwP6ndtbUyrm1j2Ea5F0\";var b=a.split(\"\").sort().join(\"\");var c=\"WjPdPvmDyU1jvUuJv\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e977446580\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/attraktor
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"lCdnTK+8aJkR_EiBoIr7yP3wzpAVh6NscGU5WM-YxQ@HuSDjZmgfv0Oe94b.tL21FXq\";var b=a.split(\"\").sort().join(\"\");var c=\"2eb.tQOuEQttbQftebdebj\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e313518383\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/augustusburg-aufweiterflur-im-lehngericht
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"M-OYDBaTR6wXd7952rc8KLqvnSJFbmEV4h3xjI.tgCu@G0iPskpZeU1o+W_AlfyNQHz\";var b=a.split(\"\").sort().join(\"\");var c=\"CP10A7CfiN0kl0_ief_Oo_P\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e124884450\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/ausbesserungswert
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Dx@j_ZySz+.c-BngQ2dkhIaGOuEVpviJtF0UCwRH1sYWATP4bl3m6Lf9eXM5KNor8q7\";var b=a.split(\"\").sort().join(\"\");var c=\"lfP9BsN5YT55TMNf45rTMK@AT\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e829030998\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/awiro-rostock
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"zsY5oajXlMhH@uL.xT3gwKF6Z87IWOUNbQA2GkmefnPB0SD4trCi1dE9J_V+cpyqv-R\";var b=a.split(\"\").sort().join(\"\");var c=\"nqrV9u+-+cSdnp+Dn11Y9V4\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e513991288\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/awo-offene-werkstatt-rudolstadt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Crzd5L3VjXKSTe+yYRWbAU@4JEp.nfFuZG-xg12lH9_MkvI68sPmO0cotDBqhQwNai7\";var b=a.split(\"\").sort().join(\"\");var c=\"I90sOsvQck0v8Be609sOzMo0\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e421380843\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/backspace-hackerspace-bamberg
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ocrs1wKMVGujp_i0mSUDBvOx97WteLEAJR5kqzZlaNX2g6yHbYQT4h+fnCF-@P8I3.d\";var b=a.split(\"\").sort().join(\"\");var c=\"8fF-@N+g_bN2T6F-nN26cXNhX6FHrg6\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e112252635\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bastelbude-grade-de
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"nI_R49UFpMKe81NWuO5JGx-BmfTbqo6S@dsztVEHhLajP.Y3vrXwycZQgA72k+DCli0\";var b=a.split(\"\").sort().join(\"\");var c=\"ZQIcLry2Igy.L2.137LP._P.\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e150982831\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bauer-planer
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vtG6l8ZIHJ9V4NoDnLBu+dxKpFag2hXiPSR@zEfyj5QrcW-A7s03kMb.ewYCmTUOq_1\";var b=a.split(\"\").sort().join(\"\");var c=\"Ysr7mWYNQ5TWYtek5bWYGcW\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e42630223\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bicycle-liberation-front-bamberg
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"aBuMhiJ3QDdwNzv9lXf24njtHU0cP7ZT+EmVWs@6_exGybOY1qLp.5oK8RIr-FSCAgk\";var b=a.split(\"\").sort().join(\"\");var c=\"x.Ouxe5xbIYzY5eq.uGK5\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e661164328\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bike-kitchen-nuernberg
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"WOJfjpEz6uMqo-c7Pe+Cx@m3baV_8DQN1L.r2IAwiHFskh4lRG5SKyZUgYv0ntXdB9T\";var b=a.split(\"\").sort().join(\"\");var c=\"FGShSGnsRhZ-vthsShZdGZkOZthvZFhvlJkh\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e492626913\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikebox
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"1nf9EhyLTSsMa4Cq2dNBVIupF8mweio3JOlk.Q-0vctGKrDx+UH6zXZP@AY_75jgWbR\";var b=a.split(\"\").sort().join(\"\");var c=\"_7r@+cZf_G+UXXrz4GjHXnxzc5G+c5fKr\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e217618816\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-augsburg
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"c.y+HLE3RkTzA1QxBu72jO9bDKI6fPmrdhstSXWlqUpvnoeiM-V8GYagNZJ540w@C_F\";var b=a.split(\"\").sort().join(\"\");var c=\"p-8o8-4vMoaqU0i5p0Ji1iYCyno\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e574024198\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-muenchen
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"7ZOWC05GLSoe4+pvxyr.usBwHUQVAY-n8bIF@h2gJXtaMcDKm13iET_k9PNzdqf6ljR\";var b=a.split(\"\").sort().join(\"\");var c=\"1_Dk+t1ici1damc_OMc\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e717549397\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bikekitchen-rosenheim
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"6EvLl+KTBp.QtkJ2PVaAqYs08RZD-hnMNd19XGCiUr4xufgoyzcHWmIb5e3Fw_S7@Oj\";var b=a.split(\"\").sort().join(\"\");var c=\"4zHfHzwxyfIk3bFfIx3zmfE4zHfx3f7vuf\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e621671621\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/binary-kitchen
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"hcqD_liesGodAHF3YPkjr61Zv9Kp@O2f8.0JSabnCEWQuw5UgVTL7xINmt-+MXzBR4y\";var b=a.split(\"\").sort().join(\"\");var c=\"zN-+MEIuHWVIE-4cLVMQgwIquw\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e591242847\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/biopunk-kitchen
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Uvu-Ti8eL_Zw4y2Vt1Gs.0K3zmpIWF6+oDCEnShAJYQcbxRfd@grHkPOlqX597NjMBa\";var b=a.split(\"\").sort().join(\"\");var c=\"r@9cdxPyj@HYlubx\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e114157694\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bonn-im-wandel
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"+AiObDCxNa9feyqM-JuT2Pj03GLsFdQh8.4V_nS5trpoUBZIglY61zRvEc@wHk7WXmK\";var b=a.split(\"\").sort().join(\"\");var c=\"lRZvypvRRAlzAWrRUB1iUB\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e125188822\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/brigkmakerspace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"l1jrvVEkLyTdam_xRM@bUnB4OpfAN-HWXJP7tIh5qi9DwcZs0ugY6eKF8CGS2Qo.3+z\";var b=a.split(\"\").sort().join(\"\");var c=\"eiYcGS8iDcm9GusYjwusu2i6\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e642035082\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/brinke-26-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"P9F84kY57H0fKeRvxndw-WBXINJ612yO_htsbqpzgGjSDCAiEaL.uZ3@VTUcQlo+mrM\";var b=a.split(\"\").sort().join(\"\");var c=\"jUa3.CkHCoeV@cQC@FDC\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e487024033\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/build-share-repair
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"5iYnMcQEyjaVlpqUu@fe0JhN6HZAgbdR3PTGrwLKX49W-_tzFvxkS21BoCsDOI87m+.\";var b=a.split(\"\").sort().join(\"\");var c=\"9IvS-DF4s_s_o4vspD+DO_24IDt4SSYBsz\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e796939192\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/bukiprojekt-buchkinder-potsdam
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"b7HTX_pZE1Koi9YclMfL42OWyCGem3qQ5ItBkg8RPwS.Usd@NvDVa-nFhzr6uJAx0j+\";var b=a.split(\"\").sort().join(\"\");var c=\"SJVvhrFDsVu9hF6usFHUs\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e607225114\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/namespace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"B5+1lnNdPyFz6w3x9chGK.pVAIZHrtL74TgQoi-e@EbXfj2MuSv_OJkU0DWaCmYR8sq\";var b=a.split(\"\").sort().join(\"\");var c=\"_UkCE_Cw2WjS2mk_5MjWE5MWjSq+fj\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e330111255\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/cafekaputt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"zs5.@31S8Ky9nGVrb-lEO4+oNjJcXwYARfBFLUTWZgQtqM7mxu_e6pCvDaikh20IHPd\";var b=a.split(\"\").sort().join(\"\");var c=\"tg7MegD2hhG6MQMC6MiCMC6MuDdum5qM\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e448223713\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/ccc-ffm
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"HRaJtcqybvSXrL5.6wZ8NFA@IGUhzDQe0x_pg714djMYoETn+K2Cmfi-kV3BWPsluO9\";var b=a.split(\"\").sort().join(\"\");var c=\"i-3EkmOLYYYRTTfaoE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e744153171\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/ccc-hh
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vscCgJ0Mi2d.ULN3ARxWQhG89K6_@T5IYZHlwbq-m1Onkz+DVoepSX7EButfa4jPyFr\";var b=a.split(\"\").sort().join(\"\");var c=\"X1oSLV1XO4tDcnnnckz\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e36696497\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/chance-action-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Bs7YtPFWDUEepAuk4+S@5hZNyLzCr8a62onfvIg-idVORlK.QMxT_0bXmH1wGJ3qjc9\";var b=a.split(\"\").sort().join(\"\");var c=\"OX__lOGM3lAOQdbOldOGMXb7Rl\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e45281433\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaoschemnitz
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"CyQBn@UYtp1RKXkFWucPboLS58JwEhrlGzH+_se0fv.AIZgm7a9iO4VT6d-jND2qx3M\";var b=a.split(\"\").sort().join(\"\");var c=\"iTVNviNXA7vTjA7Z4VaNMQIZ\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e226417038\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaosstuff
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"5wWTrPjFbI-Rm.kBQHdU_YNg9Jc7st@+neDuZ4Cahy8Gvl12xVqOi6KM0zoX3ESpfAL\";var b=a.split(\"\").sort().join(\"\");var c=\"VK1M.GjiWiE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e369892052\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/chaostreff-dortmund
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"WMODbya3-kZJzvf0xH_TRs6EQjrB97iwmSGcF5LgdpqoNhI1@VPAKCUn2ue+t4.8YlX\";var b=a.split(\"\").sort().join(\"\");var c=\"2eh++hvo@pn+tehIIMNnetC4UNONh\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e301198828\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/citylab-berlin
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"8F71xXIdl26RHNaViTgK3QstnPA_JYcErGevW-0M+pmOLhb9oCDSfqw@ujZkzy5.UB4\";var b=a.split(\"\").sort().join(\"\");var c=\"mCfLyw9NzhOow@f@9ChkzCbzyw9FmhZfCw7Lh\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e369676645\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/cocolab
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"4@3kNUirB6SoduyCWwFV2QIbpGMfvn5T7O.emZL8Dhc9EKxjgJsPz-laHAR+1t_0qXY\";var b=a.split(\"\").sort().join(\"\");var c=\"shla+9gu9a9alh1@+Hh9K39a-\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e841131609\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/code-for-heilbronn
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"jr7F.q-0VJhUsvmnuEB42dcXo+8WpblQ9fPKtMO_65@iwCSzgeGakRZTIHx1DLYNA3y\";var b=a.split(\"\").sort().join(\"\");var c=\"eZSTviTwCSTxgCek@xTZZ7wC\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e205185077\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/colorlabor
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"-v7AyautrZGS_bWP@wKT5les1EX.3gdFL2MIkjpxDOR+qCNVHhzio9mBf8JY4QUn0c6\";var b=a.split(\"\").sort().join(\"\");var c=\"+BoBJoORBJbqORChviOYYCo7qC\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e758349103\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/comakingspace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"13VbfyBtgxHCn6F29YJueSZRUQNO4k@K_sWEo7X50lv-ri.TMzGqLcadmjpD+8PAwIh\";var b=a.split(\"\").sort().join(\"\");var c=\"za.d6-dclqzaTVDml-i\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e925053914\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/coyote
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"u7wFZpB-mncHElNG_Otzi3LJbDXP@oq2xUV+6M95YhS.yWgTvCA0sRdIrkQ1ae4K8jf\";var b=a.split(\"\").sort().join(\"\");var c=\"vWssIl1aeyCIZZ-wyW\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e604104145\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/craftschoepferey
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"SCvh7r2lsncHXeWYRbD6LA8NUZ_B0zIotQEykOK5jg@1FiJwqx.m9dTMup+a3GfPV4-\";var b=a.split(\"\").sort().join(\"\");var c=\"mG+aie1+gJ3a1qMiuJi+i4vFi\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e710071839\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/creapolis-makerspace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"VlWrYZajufkG@ozeUCpNJxP-g59dKIhw728iqm_yLcbQBt4AT0XnRMsH1DvS+6E3FO.\";var b=a.split(\"\").sort().join(\"\");var c=\"Mcvn6SWst64tRBoTSlQHb6vAWBt\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e602468489\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/creativhalle-neuss
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"btAKo9ZyEVfn6hJLTNkWp_Rl5IDmwjCsG8ScdYXer-gFB7UiH1vu24@OQ0Mx.3zaP+q\";var b=a.split(\"\").sort().join(\"\");var c=\"FM7-.1zH-227AB7hi4-12AFO4\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e868718767\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/cucula
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"06dNy.jnKAzEQJo+bVeuGYZ-MhaSUqWpFmgtvf2BIPH748x5wDikR@LOTrXlC3s_1c9\";var b=a.split(\"\").sort().join(\"\");var c=\"DLxOJkDL48X6HXP37w8L6@PCl7wd48\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e600166384\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/curious-community-labs
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"GuX5Mv2sJwCNP+DQVfIExtSdAgB3zFmYbk4h.p9Kyir17qaW-oHRn08elcOTZL6@j_U\";var b=a.split(\"\").sort().join(\"\");var c=\"-qnneX@eOn7+1LOoeLTXroe\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e282230563\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/habitat-augsburg
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"-mIxUgLAakDYrbiKJyFP8hHvN_cX27oEjBV05MtQ64Z+T9lWsO@qCn3fG1RzSpue.wd\";var b=a.split(\"\").sort().join(\"\");var c=\"qf3S4qSbT4zms4ZOS4SIT9\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e321562274\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dasdigidings
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"RdBU+nJzHo@2AVaw6FyhjspGLZeTSlmX.c0WP_EDvK8Y-5rxiCQgubNt913fqkMI4O7\";var b=a.split(\"\").sort().join(\"\");var c=\"CNrtV-Kf-CxC-CNxfB-5\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e386345488\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/devlab-tsa-e-v-hackerspace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ec96wuhpP+sRoK4CE5G@DqAFMJ0ZL8S_iQW.ykUXdaf-gHmOj7TBzb1xntlvNrIY2V3\";var b=a.split(\"\").sort().join(\"\");var c=\"-x1Na-NKgHIzaf91lY\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e601968589\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dezentrale-dortmund
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"32VitBYlh5r7gwsce+o0xfEA@HqGbRkJzFya9IPm_1DKj.M6SuNTdn-XQWZL4pvUO8C\";var b=a.split(\"\").sort().join(\"\");var c=\"Npdu1VTZ18.ZwpnLuKS4VMZ1p-SXM.ZVj.\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e997772177\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dezentrale-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"u@oFARY9TGv7Ueb4gqsQ3yW6a1DMnpP+Hh0EN2OLSmjkiJKlICzfwX-drVctZB_8.x5\";var b=a.split(\"\").sort().join(\"\");var c=\"_dctZm-ieiJ5J-ZcmwJotrmkJ\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e540675191\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-blaue-blume
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"gV0GIS+kC-n2f6XJTo9tNY@pUHyd.xjh4uwrRzEQL5s8WaePmBOlAbc_DZKFMq173vi\";var b=a.split(\"\").sort().join(\"\");var c=\"bB8m5aA0macla6WBasA5qasAqba0_KP\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e773596449\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-ganzmacher-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"pNeSmM_lbIW2zyfaKd-CYhgw0Q1V9nXJr6FTZE5.x4kRPO+8jDoHuvLi7ts@qUA3cGB\";var b=a.split(\"\").sort().join(\"\");var c=\"HiLq4HqyPDON84LBv4RjOsePO\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e471858790\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-machbar
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"B29Gw751QV.b8OPTHsi3SIf4LkDFpncEt6x0XMYrgmWuyUjeRlazN_@KA-qhdZJCv+o\";var b=a.split(\"\").sort().join(\"\");var c=\"_muRWmq9yUhhmZOe_mlN9uK_\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e2953524\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-motte
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"4vBwj0udzSY-cFriG+8K5gHhA_qklJsEMeLNfmOIb3o2xXZ67apCPWyT9R.@1ntQUDV\";var b=a.split(\"\").sort().join(\"\");var c=\"ayZTFxaXqlee8BxX\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e861460663\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-radgeber
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vJ5Xe6Y4GbCtadSZ0xB.urPIU3o-8glcwEjz2yMp+V9fOKqm1sR7@WDnL_hTHQkNAFi\";var b=a.split(\"\").sort().join(\"\");var c=\"LnTHdhVOmK9KhJ@KsLism5OK\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e321403201\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/die-werke-bonn-fahrrad-selbsthilfe-werkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"3Po9ivVYpD8tKHO4g_RmEx2IwsfFkd1+C@h7nJ6STZ.-bleUrLacMjXNqQGAW50Byuz\";var b=a.split(\"\").sort().join(\"\");var c=\"GZbPLjPlLjlGHMLAWAoqNAWlNobl\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e704787117\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/digitales-aachen-e-v-digitac
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"VLZds@wUkIe-c0ufxO9t64B+K_vgGmY2lo5NzMy37DaPHhXSJr.nbiFCpAqER1jTQW8\";var b=a.split(\"\").sort().join(\"\");var c=\"jCqERDFH0HrSrRDPZPP\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e777138250\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dingfabrik
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"y4wmGoMgd3chLs7jzEDKeU+u0Xn5IAVT-1P8xJNlBiHbrOpRW.tC@vQYa296fkqSZ_F\";var b=a.split(\"\").sort().join(\"\");var c=\"aY6fsr.QRpiH9.CwrO\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e925921432\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/diy-werkstatt-karlsruhe
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"EXZe-KGx6Ql_A1CswfoWTa0HNbg.+hcPRL5tU8vMim723kI4@OJBpuDVjqnSzYr9dFy\";var b=a.split(\"\").sort().join(\"\");var c=\"VIIkDkX9knBSzmzz1nOSkYjZDkz\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e952742229\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/diy-holzwerkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"n38MWTvkZlL@-y6J+DX4wo9iQu0PhgBSmKfOE1YHVUac5FqIbNjRs2Gr_zAt7pd.xeC\";var b=a.split(\"\").sort().join(\"\");var c=\"NGqry5Ne3brsC.FARt7U7785F\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e588411531\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/do-it-yourself-werkstatt-wilhelmshaven
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"gAcMuTBtm-xYH_+4UN8ehVkvwPpWQlDbLEZ65KdX@ynjJf.79CoaS1iRIOrq2z30GFs\";var b=a.split(\"\").sort().join(\"\");var c=\"Ci.R_JCF00cJf\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e200214492\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dolab
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"AuFpLVwl@o2BkHTGr3NK+qmafjDC._xZ-4b0OhREsUJIY1zQX96ySc8gtMPniWde75v\";var b=a.split(\"\").sort().join(\"\");var c=\"YgHYgSUJFUi\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e407691859\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/dorfscheune-praedikow
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"D3ZR8pb7zo9BMKd4mw2+y@nCiJFGLrqljY5I6XcvaWVPu0kA-s_STetHgQh1UOE.xfN\";var b=a.split(\"\").sort().join(\"\");var c=\"stkHK-Hk3ghW0usSH.Zu0\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e932758612\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/druckbar
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"CdYMl5Ph6@UVJz3XHmWwc_K+78B-TovQELF9xseZ1tpigbf0D.aruqGjSkyRA2nONI4\";var b=a.split(\"\").sort().join(\"\");var c=\".Gfjzgy2irptygbRRt2Ygb\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e329801092\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/druckgrafisches-atelier
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"_aN9j2PXBcObhrV+CyxRk4HKMG6-AYfmlWn7DT5Ei3sduzFtISQv1Jo.qZLweg0U8p@\";var b=a.split(\"\").sort().join(\"\");var c=\"SoF.ruLgdvtL3FSwdIzwa3ez1SzLNuz\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e908140406\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/e-werk-oschatz
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Z54OJlvs1MPGrdCWU+7p8E_bayK@2qY-VzAuxwTcFB0QS6enkDXH.iL3ghojRNf9mtI\";var b=a.split(\"\").sort().join(\"\");var c=\"DLe3d696oH53jQkBRI4S6\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e973811241\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/ecocurious
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ZAg6lt4BIMh.m70G+_SaHqksVQWOvruJYR-U2f9deFwX@Pzb85DCoLxcyN1Ep3nijTK\";var b=a.split(\"\").sort().join(\"\");var c=\"iP7PXcX315c3Eg@P\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e386486344\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/Ehrenwerk
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Wyv9_abPQ-.L+A7u0Et61DgYXV8@KelrIUJOTGHsSqkMZzxB42h5pfFnCNo3Rmwidjc\";var b=a.split(\"\").sort().join(\"\");var c=\"t4ozFizo5AzwqBBfk4vZz\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e930716337\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/eigenbaukombinat-halle-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vcWNPX0h+TjICA5Jlue1nok.Y8rmdUBQHp9bzOV-qDFS_G4L@Eg6MR3KZ7yiwsxt2af\";var b=a.split(\"\").sort().join(\"\");var c=\"E34KAGELG3FDs6KRFE3DwW_G\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e322527035\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/enzwerk
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"-MAmrFsYB@gtf_Iz45VH3cJ1jD+Zd6KnLESh9kTlbCNXOUe0oRpxP.u8awyWQqGiv27\";var b=a.split(\"\").sort().join(\"\");var c=\"oUPP8AUu7iUyx_a8WQU8AOU\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e671522725\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/erfindergarden
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"x7n5bg-aiczVNdLj9kDYRJ@OoEq1BmQp_Uu8Kt4WIyvPS0Th.3HAfe2CsXGwlr6+ZMF\";var b=a.split(\"\").sort().join(\"\");var c=\"sfyMd0GT32S0GhyGS02nS0\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e1096318\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/freie-maker
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"eRp8tV1FTzBgkbPD5jq@A3U6+MJv.miQIKLGsO72a_xZl4X0uN-EHWrocfySYw9nCdh\";var b=a.split(\"\").sort().join(\"\");var c=\"9oySY_rlbXy4N4RW_E4ypl4\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e126420956\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fabulous-st-pauli
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"8CAFWh+okMUgEBJbR5yiTvN0L2Q-_V1GYd469fZ3xXjlzKnrwIpDP7SauOmcqset@H.\";var b=a.split(\"\").sort().join(\"\");var c=\"eatcIqKBnXjPXjCwX7jsmrAamr\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e471239340\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fab66
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ZaLnSBlDGCNzTx9eHymg4fk.uv02b3wjhrR+Eo5UcK8W@6JId-1PMsqQOYVA7_XpitF\";var b=a.split(\"\").sort().join(\"\");var c=\"dKMMQxJK8CCL@6\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e350257441\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-aachen
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ZSnF@kwl0VIsqvJWgoY71Nhj+frzXHbAOp-Qy8RMTULd_Pu5E3xtBD4m2cGiaC9K6.e\";var b=a.split(\"\").sort().join(\"\");var c=\"xU4naEUGvGKaESUUdEP4n_P\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e476115307\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-altmuehlfranken
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Wi2K-sN8yxPX3ojTwSL@.6r5ugC1A9ME07adYmF+JHpzVvDfhQtUGlbcR_4IeZOnqBk\";var b=a.split(\"\").sort().join(\"\");var c=\"Oc4IeHbVoDHpGHpiHGelZvhGD4HbUvb2Vv\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e84276382\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ansbach
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"rD-n_EIv9Ho3SNwXLY5.u6gq7B8ejAPpOFly1GzhmbMdfk+cC0axU4Kt@2ZRQWsJTiV\";var b=a.split(\"\").sort().join(\"\");var c=\"0K+tN+bMUbMDbKRMbdC-fk\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e111320704\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-bruchsal
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\".JkjICT6tXQLunO19+_Avq0f4d7arESy8F2gc@esomwi-BDWV5hYlNUZzMPpGRb3KHx\";var b=a.split(\"\").sort().join(\"\");var c=\"bBPB5UnDmwlmwJwPRiVpmlk-B\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e122930190\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablabc
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"nO_QgjNekS0W6wGXoUt-xP1lsYFLcC.m5JupDa7vA9Zq8fEiyMzTVb2+@H34hRIdrBK\";var b=a.split(\"\").sort().join(\"\");var c=\"s+2h9Thw4h98hE9Z3MT92hf2_+3i\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e129995829\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-cottbus
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"92a7xW3RlivSYtO56qLujo8fsIAn_MhFezJEk4VcCUgdpXbQGr1-N+Dy.HmBZwPK@T0\";var b=a.split(\"\").sort().join(\"\");var c=\"rDbytbUgNUg2dyZZgwBapX\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e856139089\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-frechen
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"c_USZXqMKu3Dx0sE1fT@mv5kniPoQW9gF6Olh+b8RLCYVedNwy-zJHa.prtGI27j4BA\";var b=a.split(\"\").sort().join(\"\");var c=\"yad.0dLCJLC_dteYweaUVe\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e778225140\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-freising
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"EDt82gN+1FjLOQsB67v.zwr0iAKah9UGWXedPoV3xyCJ@cmflk4Y_nIRZ-u5TMHpqSb\";var b=a.split(\"\").sort().join(\"\");var c=\"kImRQmyC_yCDmuck5kIftRuf\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e541581252\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-hamm
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"eJHr1m4OunzlfRaqb_cZ+p9isP7tSg.25Xd0GLyYo3wWNh8-B@TjEQCFkvIxKAMVUD6\";var b=a.split(\"\").sort().join(\"\");var c=\"@C8FR83wE3wJB3QQHNh\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e398710447\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ideenreich
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"psPrinoE8fqd9xLQN1I67+ekcOla3BWXVS5jDTgHzJMmutb-KZyvUw._A@0GF2RC4hY\";var b=a.split(\"\").sort().join(\"\");var c=\"Zutt.0tZmKxKGsbUt.GM20-Put\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e780847965\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-ingolstadt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"-pk5Rt+lhgHFSB2CNIzemfKYnUdWZ6Q.j3TXMrcPo4@70xOEyi1qAV_uvLD8bsGJw9a\";var b=a.split(\"\").sort().join(\"\");var c=\"i_OuBO4@A4@pi_EuA8b40bk0x\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e368562372\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-karlsruhe-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"AizEC54ORTDLryMaZV3g.Y8BHev6N2wXxcPUkq1KWIod9jGFJl-ufsS@n0h_ptm7bQ+\";var b=a.split(\"\").sort().join(\"\");var c=\"fIolSG@yGIofIoiuIhf_htJjz9j\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e742246126\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-kiel
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"awAbS71PgUp6DyIn-uGYLZq0vi5rVtKF.@OoJCelEBkfHzjN3s+_m28c9dRXxhWQ4TM\";var b=a.split(\"\").sort().join(\"\");var c=\"s8jcyjBkmBkAX3\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e437656363\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-landkreis-fuerth-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"kTI09rOoL_.pgCAce@tn52WRNBhxEDuVG8UMaJ3q-1dvisYj4y6mHbP7FQzlwS+ZKXf\";var b=a.split(\"\").sort().join(\"\");var c=\"yPY7CY1dH1dTYSszw4Iis\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e338919381\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-leipzig
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\".KGuhNds@DRFXeLI_H5km0BUVSWcjy+1oi8CPrwtlqEY-T96g2b74p3MJQOanZzxvAf\";var b=a.split(\"\").sort().join(\"\");var c=\"YM3nqYne9qE4qEK4T2Jf26G-T\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e3410057\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-lengerich
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"fSR.MJ7XYBmiIv1wkcyubA@s+xZVGaepgdWjhzH_9EqL-OKN540QD683ntrPl2oUFCT\";var b=a.split(\"\").sort().join(\"\");var c=\"48K3v62O8PlOrDE8-R-4N4lED\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e475932573\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-luebeck
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"wCPaZcoq9rpM@8Nkth+4WBS15lsGOgY_ER.Xx2U-DTFIvyHmKVL6fjJe3ud0A7nQbzi\";var b=a.split(\"\").sort().join(\"\");var c=\"VJHe8HTFfTFCf7yFyI6Pvy\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e433978163\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/fablab-lueneburg
# ...
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"bFsEma-cvHnDrQ.OwJRALUCB1t_Tuj5i6+gplZoN7MS2q43kYX8@KW0ehzdxy9GPfIV\";var b=a.split(\"\").sort().join(\"\");var c=\"@e0yM@yQP4d@dM9WFM9kxS9dksq4\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e783285301\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkraum47
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"t7+cxBd3k8i4_baROsUlSv9gyKC6e5W@qrY-nH2oA0Qh1MLVpJPuGD.TZfzFENXmwjI\";var b=a.split(\"\").sort().join(\"\");var c=\"J.LTbmMzuz0ND3i+1M\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e717825832\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werksalon-co-making-space
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"GrUFj3H7SqtdY9.QDbeilEKhoTwk@_+X250a1JM8xuAs-fIvcyzC4PBONZmpLnVgW6R\";var b=a.split(\"\").sort().join(\"\");var c=\"yBIO9gfmCpu4OBUuL\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e980397818\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkschule-lambach
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"LUhy4aYm1KoDjBlHEp-TFSMeGQ8ONX3qc7wPAf.z5bWs2i@VZR_JrgdCtxk0u+Ivn96\";var b=a.split(\"\").sort().join(\"\");var c=\"2iRdiBvikJ0sZ+rihbu\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e435201190\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"ToSguiPRe4ax-_s7m1NfXKpIdbFz8EDUj@nVQGC95rH6lLY+hZyv3tM02O.wcqBAWJk\";var b=a.split(\"\").sort().join(\"\");var c=\"pMY0_wrMlL.whrqwSlL\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e311606131\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadthall
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"2kJeW_vDLYhNy5GS0zIP-XQU96qVdRT7l+ArxCFw3Ei1Ojocus@atpBZ4f.Hb8nKmgM\";var b=a.split(\"\").sort().join(\"\");var c=\"Kj.aHbEOb54ZHbjZJOj\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e207270346\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstadthaus
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"1gAZJykdu4YWmh72p8aHbKC@s0XIE3oqUR+QMBzT9n5VlxD.wfjtSPevGiOc6FrLN_-\";var b=a.split(\"\").sort().join(\"\");var c=\"feDvhLxOtc6nl6wnFcAlx\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e719407767\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-hoeflich
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"30WCqB2Amw6junSx7YyOkR_Nh.D-a51TeXF9i@Lob48VZsEpcfgPQGHUKvztIrJdlM+\";var b=a.split(\"\").sort().join(\"\");var c=\"fHEUndszPtI4II0cUsEQfVcWZs\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e776055990\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-im-jukuz
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"-1UespcXFoM+CWHnrQN8iKYR7xTjVatw5mA.0J3yh@zIkEqv2S_gPfGd6B9ODl4LbuZ\";var b=a.split(\"\").sort().join(\"\");var c=\"LE9gOD@EDDEGW_lglZUkE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e1212444\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-karli17
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"akABs49CYiEQ8HXyrt0KhlmVT6_.g+vZMW735cGSwqDnpUfd1FLR@ex-JIoOzNbuP2j\";var b=a.split(\"\").sort().join(\"\");var c=\"LAp-xxUoHqdkDN1@OzoqOOUApU\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e772368367\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatt-lindenau
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"wfAk.xl3c+OPa_rQRVsn7vjeBpz9YD5W@GqyuLZFb1mCh2ESHiU8NId6XogKM0Tt4J-\";var b=a.split(\"\").sort().join(\"\");var c=\"t2g8KM1MMfNidh2d10_X6KM26Ah2\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e194635786\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattcouch
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"vCLGcDpAsyejPh_YlHBdMnQiVtrmT0z723Z9Xf+SJEN5WFo1@b8O-xgU.q6IRKkau4w\";var b=a.split(\"\").sort().join(\"\");var c=\"bgoUhaF6OIRERR5UK5@LER\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e473575551\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstaetten-im-horte-soziales-zentrum
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"NV534xOHPhDyc9XRQs2MrU1b6ml8LW._+0gwjAvIzfutSip7CZe-oYkTBnE@GaFdJqK\";var b=a.split(\"\").sort().join(\"\");var c=\"ZkpT9CTEGiV@Eu5Si\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e718264820\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstaetten-im-museum-altranft
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"YUEAkvLwPMBj7ryNXzF9h5tus3@8xJoZ4WdcQq2VmKiDfISe-l.+6Cp1a0TbgOG_HRn\";var b=a.split(\"\").sort().join(\"\");var c=\"+E_lpgITr1fITiTOD-CObIOCEfI\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e929742015\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/traumschule-riebau
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"UGLuY7sKF@vQT.OCn+tIw_hfHdgZWakS1e5oB6xci28zrpNqm4PMjbXlD09AyR3J-VE\";var b=a.split(\"\").sort().join(\"\");var c=\"y92RbAzmRjp.94ApRDLXpy\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e177365646\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatthaus
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"tgTRBOc3o5dz0NX-k+@AHw_pmWPGh8ns1yLuibvKe4Slq6arM9UxfIYCD27jFVZ.EJQ\";var b=a.split(\"\").sort().join(\"\");var c=\"9YaCN.67xjF4FFM4VjTY6F\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e31333981\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstatthaus-allerhand-e-v
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"z1IONHiq+0hr_jVcRvMeg6tSbL3Xm4x7AdKTonFwQlpCB@U8PfJGDs9ayWE5.uk-2ZY\";var b=a.split(\"\").sort().join(\"\");var c=\"-@EG5.l..jya5.@aIB@\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e210631579\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattkollektiv-plan-b
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"5NZIMDPAVbwnd437BTsmoGOJ+0_lyjqXRrSiKvg@9Cu.WYx6-2kHUQeEpfhLa1zctF8\";var b=a.split(\"\").sort().join(\"\");var c=\"cYhHLaCaaHEUUYHa2z9pUCe9u46QtZeYa\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e972824754\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattkonsum
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"7WGQlq2D-3kfyMwIZPBv9NY@S.ugAdtR0XxLO86nE1TocbpUiaVH_5JmhrCFKzj+4es\";var b=a.split(\"\").sort().join(\"\");var c=\"aJpmM+bCHFK1KKHmJFz5Gcb\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e379399778\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/werkstattraum
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"dZgTXVm4v1zhe9fDGNR03b5SwQFkrl87uIHUaBjWq+_yYKsEPAnxitMCL6-@po.cJ2O\";var b=a.split(\"\").sort().join(\"\");var c=\"cK-x@p+ppp-+ot9Et+AigyCt\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e88473536\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wir-werkstudio-im-richardkiez
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"@b0UvdLm8lz6Dgh7N.XcGtYO1xJoai29-F3k4V+rCRsBjn5STIHwW_qfMKyZpPeQAEu\";var b=a.split(\"\").sort().join(\"\");var c=\"fTZngfqWIqn0jn\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e851650463\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wir-bauen-zukunft
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"aCG61+ItwrPHb@c-3qLWxK.mzys05gTOilM9QhZF4SpuAvo_XDdEJfVY7eBN8Rkj2nU\";var b=a.split(\"\").sort().join(\"\");var c=\"jvBEXSJJv@jDBpSRvVURERVo8GAv\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e61481711\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wirfoerdern-e-v-offene-werkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"@9HsxAgpUl-w17I8X6Z5te4KCLqDhmdGbyTPQYMvjfzuBaJSiR_EoOF.3rNW2n+Vkc0\";var b=a.split(\"\").sort().join(\"\");var c=\"3.W29VRNJ.aNBaNF7SOkHBa\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e717575016\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wolkenschachlenk-werkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"gsujxoIOSM@LCdfZbw0Yic.X351qT6vFRBkhmAU2478PDEntze+H-KGaQ9yWpJrN_lV\";var b=a.split(\"\").sort().join(\"\");var c=\"HaGp7HpdKEzyNEtsEruDE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e417251173\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wucholtzky
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"BU3eFuwvWy9ZG4h6-.tML5S0V+Yi@2Iodb1cnARXmpNzOExk_lg8TDJsajKrfQCPqH7\";var b=a.split(\"\").sort().join(\"\");var c=\"_pTTs4PQz_sTf78H3OE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e253468444\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/wurmloch
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"dlRZPL-m.NhfHKjEievco1S05yqU8O_aInrs9tpxTu@QJ+F6BgWzkXwbG74MYD2AC3V\";var b=a.split(\"\").sort().join(\"\");var c=\"BukkbKAD4XkbQBRJ+\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e145055698\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/xhain-hack-makerspace
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"@mSKzQaLAZs2I9XwJntiM84cyod_OP+5N-YGvTeEg3jfqpbDBuVUWC1k0xh6HlR.7Fr\";var b=a.split(\"\").sort().join(\"\");var c=\"u1bk97B3u1Sqp\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e254532383\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/xyz-cargo-n55-till-wolfer
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Q5ZkycSz.b_xKHdnA4XjiJq3BT09a2sVvotwueRLGgpWYNIUD1hE-Cfm8rFM7P+O@l6\";var b=a.split(\"\").sort().join(\"\");var c=\"71--Hf..ZYE\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e407901734\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/z-bau-nordgarten
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"B0brJNsadLkwvo5ZGP_4Y6t8KVxCj1mElFQS7qXWze.HRiInO-cp+Myh@3AT9DufU2g\";var b=a.split(\"\").sort().join(\"\");var c=\"hAneoyhARneA9iybyi9\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e757997289\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/zam
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"k+-RIDE7xUgzelv3ZQ6Pb2X1OinjsFAhpMNo4t8Lrq0y.YGKWa@wBVd9_muSJ5HfcCT\";var b=a.split(\"\").sort().join(\"\");var c=\"w9dJqwJlTqV-Wq5S\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e583792684\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/zircula-lab
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"_Bav4bGZV7QKYtIgF@s8duUxc35N1q-k.rHASwEzfMD9Jm+2jnCiTOXWyRLphoeP06l\";var b=a.split(\"\").sort().join(\"\");var c=\"TMDBDLmOmLjMemXtlnL9oTMaWL2\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e626971271\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/makerspace-suedpfalz
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\".A7bYCUf_ytZIJ6D1+XjqxFrTHMvE9VWl@RPhOBs5ngSw-c8umG30LeNkoK2zdp4Qai\";var b=a.split(\"\").sort().join(\"\");var c=\"mecNJiz072knS-\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e57042742\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/zum-rostigen-ross
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"XtazqfhG6B_YnAcyEiRSoVQCUP0eNxH5pl1kuOZsJbr-KdmjD3@gT4+L27vM9wF8W.I\";var b=a.split(\"\").sort().join(\"\");var c=\"3+mLAvLM93jdMtvLMMaKd\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e820263869\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/zwanzig-selbsthilfe-fahrradwerkstatt
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Y-JWD4OXCSr1cdAvosj3K6tguemfPIwQZHbyMz27FExk5@iL9qh+pVl_.Na0nGTU8BR\";var b=a.split(\"\").sort().join(\"\");var c=\"iE9aaE5U@a+0nEnndE0nEJnG-5EaV0nE5nJ5@\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e800926665\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>
# 200
# https://www.offene-werkstaetten.org/werkstatt/zweiradcaf
# <script type="text/javascript">/*<![CDATA[*/eval("var a=\"Q.Fah6Dn91cLwTYoN-HAmiy_tRp+kzBsS0jqUZd2Wve8M@x5GlOuV3IEKfrg7JXb4PC\";var b=a.split(\"\").sort().join(\"\");var c=\"Cb@lrvM8vx@T534FM@\";var d=\"\";for(var e=0;e<c.length;e++)d+=b.charAt(a.indexOf(c.charAt(e)));document.getElementById(\"e597489285\").innerHTML=\"<a href=\\\"mailto:\"+d+\"\\\">\"+d+\"</a>\";")/*]]>*/</script>

# %%
output = transform.drop(columns=['img', 'street', 'street_nr', 'aai', 'cats', 'url', 'icm', 'web'])

# %%
output.to_csv('iopa_offene_output_' + now.strftime("%Y_%m_%d_%H%M") + '.csv')
