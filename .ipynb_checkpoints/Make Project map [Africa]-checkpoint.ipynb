# %% [markdown]
# <img src="https://pbs.twimg.com/profile_images/1092394418135539713/eplLRcDN_400x400.jpg" width=80px style="text-align:right"><h1>The Internet of Production Alliance </h1>
#
# ## Preliminary data report for the [Make Project](https://makeafricaeu.org/)

# %% [markdown]
# Autor: Antonio de Jesus Anaya Hernandez, DevOps eng. for the IoPA.
#
# Autor: The internet of Production Alliance, 2023.
#
# Data was collected by "Fab Foundation", location: https://api.fablabs.io/0/labs.json
#
# The Open Know Where (OKW) Standard is part of the Internet of Production Alliance and its members.
#
# License: CC BY SA
#
# ![CC BY SA](https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-sa.svg)

# %% [markdown]
# Python code used to download, parse, filter, sort and map the data:

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
import requests

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
url = "https://api.fablabs.io/0/labs.json"
response = requests.get(url)
data = response.json()

# %%
df = pd.DataFrame(data)

# %%
df = df.drop(columns=['parent_id', 'blurb', 'avatar_url', 'header_url', 'capabilities', 'links'])

# %%
df
# Out:
#         id                    name kind_name  \
# 0     2386            Al Jazri Lab   fab_lab
# 1       20  FabLab INSA Strasbourg   fab_lab
# 2     1087     la FABrique du Loch   fab_lab
# 3       17                    PiNG   fab_lab
# 4      793           FabLab Zagreb   fab_lab
# ...    ...                     ...       ...
# 2204    13           Fab Lab Egypt   fab_lab
# 2205  2201              Studio 5/6   fab_lab
# 2206  1587        TechWorks Amman    fab_lab
# 2207  1730       BISCAST ManFabLab   fab_lab
# 2208  2210         FabLab L'Aquila   fab_lab
#
#                                             description                  slug  \
# 0     The lab is equipped with cutting-edge technolo...            aljazrilab
# 1                                                  None  fablabinsastrasbourg
# 2     Le Fablab du Pays d'Auray\r\nLa FABrique du Lo...      lafabriqueduloch
# 3                                                  None                  ping
# 4     FabLab in Zagreb is first in Croatia founded t...              fablabhr
# ...                                                 ...                   ...
# 2204  Fab Lab Egypt (under the umbrella of San3a Tec...           fablabegypt
# 2205  The vision of the STUDIO 5/6 is to provide chi...              studio56
# 2206  TechWorks is CPF’s flagship innovation platfor...          fablabjordan
# 2207  Formed between the partnership of Bicol State ...      biscastmanfablab
# 2208  FabLab L’Aquila Association\r\n\r\nL'Aquila's ...              fablabaq
#
#                                        address_1  \
# 0                  House of Wisdom, Al Juraina 1
# 1                                           None
# 2                           2 place Raoul Dautry
# 3                                           None
# 4                                       Ilica 69
# ...                                          ...
# 2204   Villa 35 - 100 St. - Near Al Horia Square
# 2205  Diplomatic street, Lotus Tower, West Bay,
# 2206                  King Hussein Business Park
# 2207                         98 Penafrancia Ave.
# 2208                     Via Giuseppe Mezzanotte
#
#                                               address_2        city  \
# 0
# 1                                                  None  Strasbourg
# 2                                                             Auray
# 3                                                  None      Nantes
# 4                                                            Zagreb
# ...                                                 ...         ...
# 2204                                              Maadi       Cairo
# 2205                                                           Doha
# 2206                                        Building 23       Amman
# 2207  1st floor, College of Engineering and Architec...   Naga City
# 2208                            C/O IIS "Amedeo D'Aosta    L'Aquila
#
#                 county postal_code country_code   latitude   longitude  \
# 0              Sharjah                       AE        NaN         NaN
# 1               Alsace       67000           FR  48.583148    7.747882
# 2                            56400           FR  47.668395   -2.986011
# 3     Pays de la Loire       44000           FR  47.218371   -1.553621
# 4               Zagreb       10000           HR  45.812096   15.965438
# ...                ...         ...          ...        ...         ...
# 2204             Cairo                       EG  29.959218   31.252782
# 2205             Qatar                       QA  25.328300   51.531950
# 2206            Jordan                       JO  31.971502   35.832792
# 2207     Camarines Sur        4400           PH  13.636209  123.199228
# 2208          L'Aquila       67100           IT  42.354660   13.413750
#
#                                           address_notes            phone  \
# 0     Al Jazri Lab is located in Mezzanine Floor at ...    0097165940000
# 1                                                  None             None
# 2                                                        00 33 789028357
# 3                                                  None             None
# 4                                                           +38513755436
# ...                                                 ...              ...
# 2204                                                       +201017465650
# 2205             This is a temporary location, Floor 10    +974 33556554
# 2206           Next to GROW Building side door entrance   00962791000110
# 2207
# 2208                                                       +393927629526
#
#                             email activity_status
# 0     aljazrilab@houseofwisdom.ae          active
# 1                            None            None
# 2      lafabriqueduloch@gmail.com          active
# 3                            None            None
# 4                  info@fablab.hr          active
# ...                           ...             ...
# 2204    fablabegypt@san3atech.com          active
# 2205             info@studio56.qa          active
# 2206            info@techworks.jo          active
# 2207  biscast.manfablab@gmail.com          active
# 2208          info@fablaquila.org          active
#
# [2209 rows x 17 columns]
